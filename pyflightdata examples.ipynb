# %% [markdown]
# # pyflightdata examples
#
# This document lists a few examples to show the basic usage of pyflightdata. This does not show all the potential uses of the data we get from the API.
#
# Please note that this is not an official API and we do not endorse or recommend any commercial usage of this API to make large scale mass requests.
#
# Also the API may break from time to time as the pages and their structure change at the underlying websites. For now this is only flightradar24.com but we might add more sites soon.

# %%
from pyflightdata import *

# %%
get_countries()[:5]
# Out:
# [{'country': 'Afghanistan',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/afghanistan.gif'},
#  {'country': 'Albania',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/albania.gif'},
#  {'country': 'Algeria',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/algeria.gif'},
#  {'country': 'Angola',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/angola.gif'},
#  {'country': 'Anguilla',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/anguilla.gif'}]

# %%
get_airlines()[:5]
# Out:
# [{'airline-code': '-dornier-aviation-nigeria-aiep-do-dav',
#   'callsign': 'DO / DAV',
#   'fleet-size': '3 aircraft',
#   'title': '\tDornier Aviation Nigeria Aiep'},
#  {'airline-code': '-latam-airlines-ecuador-xl-lne',
#   'callsign': 'XL / LNE',
#   'fleet-size': '6 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/LNE_logo0.png',
#   'title': '\tLATAM Airlines Ecuador'},
#  {'airline-code': '9-air-aq-jyh',
#   'callsign': 'AQ / JYH',
#   'fleet-size': '8 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/JYH_logo0.png',
#   'title': '9 Air'},
#  {'airline-code': 'abx-air-gb-abx',
#   'callsign': 'GB / ABX',
#   'fleet-size': '14 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ABX_logo0.png',
#   'title': 'ABX Air'},
#  {'airline-code': 'adria-airways-jp-adr',
#   'callsign': 'JP / ADR',
#   'fleet-size': '13 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ADR_logo0.png',
#   'title': 'Adria Airways'}]

# %%
get_airports('India')[10:15]
# Out:
# [{'iata': 'BHU',
#   'lat': '21.752199',
#   'lon': '72.185181',
#   'name': 'Bhavnagar Airport'},
#  {'iata': 'BHO',
#   'lat': '23.28746',
#   'lon': '77.337372',
#   'name': 'Bhopal Raja Bhoj Airport'},
#  {'iata': 'BBI',
#   'lat': '20.24436',
#   'lon': '85.81778',
#   'name': 'Bhubaneswar Biju Patnaik International Airport'},
#  {'iata': 'BHJ',
#   'lat': '23.287821',
#   'lon': '69.670143',
#   'name': 'Bhuj Airport'},
#  {'iata': 'IXC',
#   'lat': '30.67346',
#   'lon': '76.788544',
#   'name': 'Chandigarh Airport'}]

# %%
#pass the airline-code from get_airlines
get_fleet('emirates-ek-uae')
# Out:
# [{'aircraft-regs': ['A6-EAF',
#    'A6-EAK',
#    'A6-EAQ',
#    'A6-EAR',
#    'A6-EAS',
#    'A6-EKT',
#    'A6-EKU',
#    'A6-EKV',
#    'A6-EKX',
#    'A6-EKY'],
#   'aircraft-type': 'A332',
#   'count': '10'},
#  {'aircraft-regs': ['A6-ERM', 'A6-ERN', 'A6-ERO', 'A6-ERP'],
#   'aircraft-type': 'A343',
#   'count': '4'},
#  {'aircraft-regs': ['A6-EDA',
#    'A6-EDB',
#    'A6-EDC',
#    'A6-EDD',
#    'A6-EDE',
#    'A6-EDF',
#    'A6-EDG',
#    'A6-EDH',
#    'A6-EDI',
#    'A6-EDJ',
#    'A6-EDK',
#    'A6-EDL',
#    'A6-EDM',
#    'A6-EDN',
#    'A6-EDO',
#    'A6-EDP',
#    'A6-EDQ',
#    'A6-EDR',
#    'A6-EDS',
#    'A6-EDT',
#    'A6-EDU',
#    'A6-EDV',
#    'A6-EDW',
#    'A6-EDX',
#    'A6-EDY',
#    'A6-EDZ',
#    'A6-EEA',
#    'A6-EEB',
#    'A6-EEC',
#    'A6-EED',
#    'A6-EEE',
#    'A6-EEF',
#    'A6-EEG',
#    'A6-EEH',
#    'A6-EEI',
#    'A6-EEJ',
#    'A6-EEK',
#    'A6-EEL',
#    'A6-EEM',
#    'A6-EEN',
#    'A6-EEO',
#    'A6-EEP',
#    'A6-EEQ',
#    'A6-EER',
#    'A6-EES',
#    'A6-EET',
#    'A6-EEU',
#    'A6-EEV',
#    'A6-EEW',
#    'A6-EEX',
#    'A6-EEY',
#    'A6-EEZ',
#    'A6-EOA',
#    'A6-EOB',
#    'A6-EOC',
#    'A6-EOD',
#    'A6-EOE',
#    'A6-EOF',
#    'A6-EOG',
#    'A6-EOH',
#    'A6-EOI',
#    'A6-EOJ',
#    'A6-EOK',
#    'A6-EOL',
#    'A6-EOM',
#    'A6-EON',
#    'A6-EOO',
#    'A6-EOP',
#    'A6-EOQ',
#    'A6-EOR',
#    'A6-EOS',
#    'A6-EOT',
#    'A6-EOU',
#    'A6-EOV',
#    'A6-EOW',
#    'A6-EOX',
#    'A6-EOY',
#    'A6-EOZ',
#    'A6-EUA',
#    'A6-EUB',
#    'A6-EUC',
#    'A6-EUD',
#    'A6-EUE'],
#   'aircraft-type': 'A388',
#   'count': '83'},
#  {'aircraft-regs': ['OO-THC', 'OO-THD'],
#   'aircraft-type': 'B744',
#   'count': '2'},
#  {'aircraft-regs': ['A6-EMG', 'A6-EMI', 'A6-EMJ', 'A6-EMK', 'A6-EML'],
#   'aircraft-type': 'B772',
#   'count': '5'},
#  {'aircraft-regs': ['A6-EMM',
#    'A6-EMN',
#    'A6-EMO',
#    'A6-EMP',
#    'A6-EMQ',
#    'A6-EMR',
#    'A6-EMS',
#    'A6-EMT',
#    'A6-EMU',
#    'A6-EMV',
#    'A6-EMX'],
#   'aircraft-type': 'B773',
#   'count': '11'},
#  {'aircraft-regs': ['A6-EFD',
#    'A6-EFE',
#    'A6-EFF',
#    'A6-EFG',
#    'A6-EFH',
#    'A6-EFI',
#    'A6-EFJ',
#    'A6-EFK',
#    'A6-EFL',
#    'A6-EFM',
#    'A6-EFN',
#    'A6-EFO',
#    'A6-EFS',
#    'A6-EWA',
#    'A6-EWB',
#    'A6-EWC',
#    'A6-EWD',
#    'A6-EWE',
#    'A6-EWF',
#    'A6-EWG',
#    'A6-EWH',
#    'A6-EWI',
#    'A6-EWJ'],
#   'aircraft-type': 'B77L',
#   'count': '23'},
#  {'aircraft-regs': ['A6-EBA',
#    'A6-EBB',
#    'A6-EBC',
#    'A6-EBD',
#    'A6-EBE',
#    'A6-EBF',
#    'A6-EBG',
#    'A6-EBH',
#    'A6-EBI',
#    'A6-EBJ',
#    'A6-EBK',
#    'A6-EBL',
#    'A6-EBM',
#    'A6-EBN',
#    'A6-EBO',
#    'A6-EBP',
#    'A6-EBQ',
#    'A6-EBR',
#    'A6-EBS',
#    'A6-EBT',
#    'A6-EBU',
#    'A6-EBV',
#    'A6-EBW',
#    'A6-EBX',
#    'A6-EBY',
#    'A6-EBZ',
#    'A6-ECA',
#    'A6-ECB',
#    'A6-ECC',
#    'A6-ECD',
#    'A6-ECE',
#    'A6-ECF',
#    'A6-ECG',
#    'A6-ECH',
#    'A6-ECI',
#    'A6-ECJ',
#    'A6-ECK',
#    'A6-ECL',
#    'A6-ECM',
#    'A6-ECN',
#    'A6-ECO',
#    'A6-ECP',
#    'A6-ECQ',
#    'A6-ECR',
#    'A6-ECS',
#    'A6-ECT',
#    'A6-ECU',
#    'A6-ECV',
#    'A6-ECW',
#    'A6-ECX',
#    'A6-ECY',
#    'A6-ECZ',
#    'A6-EGA',
#    'A6-EGB',
#    'A6-EGC',
#    'A6-EGD',
#    'A6-EGE',
#    'A6-EGF',
#    'A6-EGG',
#    'A6-EGH',
#    'A6-EGI',
#    'A6-EGJ',
#    'A6-EGK',
#    'A6-EGL',
#    'A6-EGM',
#    'A6-EGN',
#    'A6-EGO',
#    'A6-EGP',
#    'A6-EGQ',
#    'A6-EGR',
#    'A6-EGS',
#    'A6-EGT',
#    'A6-EGU',
#    'A6-EGV',
#    'A6-EGW',
#    'A6-EGX',
#    'A6-EGY',
#    'A6-EGZ',
#    'A6-ENA',
#    'A6-ENB',
#    'A6-ENC',
#    'A6-END',
#    'A6-ENE',
#    'A6-ENF',
#    'A6-ENG',
#    'A6-ENH',
#    'A6-ENI',
#    'A6-ENJ',
#    'A6-ENK',
#    'A6-ENL',
#    'A6-ENM',
#    'A6-ENN',
#    'A6-ENO',
#    'A6-ENP',
#    'A6-ENQ',
#    'A6-ENR',
#    'A6-ENS',
#    'A6-ENT',
#    'A6-ENU',
#    'A6-ENV',
#    'A6-ENW',
#    'A6-ENX',
#    'A6-ENY',
#    'A6-ENZ',
#    'A6-EPA',
#    'A6-EPB',
#    'A6-EPC',
#    'A6-EPD',
#    'A6-EPE',
#    'A6-EPF',
#    'A6-EPG',
#    'A6-EPH',
#    'A6-EPI',
#    'A6-EPJ',
#    'A6-EPK',
#    'A6-EPL',
#    'A6-EPM',
#    'A6-EPN',
#    'A6-EPO',
#    'A6-EPP',
#    'A6-EPQ'],
#   'aircraft-type': 'B77W',
#   'count': '121'}]

# %%
#pass airline-code from get_airlines to see all current live flights
get_flights('emirates-ek-uae')[:10]
# Out:
# [{'aircraft': 'A6-EDS',
#   'aircraft-type': 'A388',
#   'flight': 'EK4',
#   'from': 'London Heathrow Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-EDX',
#   'aircraft-type': 'A388',
#   'flight': 'EK6',
#   'from': 'London Heathrow Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-EDW',
#   'aircraft-type': 'A388',
#   'flight': 'EK7',
#   'from': 'Dubai International Airport, United Arab Emirates',
#   'to': 'London Heathrow Airport, United Kingdom'},
#  {'aircraft': 'A6-EOA',
#   'aircraft-type': 'A388',
#   'flight': 'EK10',
#   'from': 'London Gatwick Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-EEW',
#   'aircraft-type': 'A388',
#   'flight': 'EK11',
#   'from': 'Dubai International Airport, United Arab Emirates',
#   'to': 'London Gatwick Airport, United Kingdom'},
#  {'aircraft': 'A6-EOY',
#   'aircraft-type': 'A388',
#   'flight': 'EK20',
#   'from': 'Manchester Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-EGG',
#   'aircraft-type': 'B77W',
#   'flight': 'EK21',
#   'from': 'Dubai International Airport, United Arab Emirates',
#   'to': 'Manchester Airport, United Kingdom'},
#  {'aircraft': 'A6-EPC',
#   'aircraft-type': 'B77W',
#   'flight': 'EK26',
#   'from': 'Glasgow International Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-EOB',
#   'aircraft-type': 'A388',
#   'flight': 'EK32',
#   'from': 'London Heathrow Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'},
#  {'aircraft': 'A6-ENA',
#   'aircraft-type': 'B77W',
#   'flight': 'EK38',
#   'from': 'Birmingham Airport, United Kingdom',
#   'to': 'Dubai International Airport, United Arab Emirates'}]

# %%
get_history_by_flight_number('AI101')[-5:]
# Out:
# [{'aircraft': {'hex': '8003E4',
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'owner': 'Air India',
#    'registration': 'VT-ALL',
#    'serialNo': '36310'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': 40.639751,
#      'longitude': -73.7789,
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EDT',
#      'abbrName': 'Eastern Daylight Time',
#      'isDst': True,
#      'name': 'America/New_York',
#      'offset': -14400},
#     'visible': True},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 28.5665,
#      'longitude': 77.103081,
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': None,
#    'id': 'a9eff79',
#    'number': {'alternative': None, 'default': 'AI101'},
#    'row': 3248801266},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470813081, 'utc': 1470827481},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 07:11'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470827481, 'updated': 1470828439},
#    'real': {'arrival': 1470827460, 'departure': 1470776471},
#    'scheduled': {'arrival': 1470828300, 'departure': 1470773700}}},
#  {'aircraft': {'hex': '8003E4',
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'owner': 'Air India',
#    'registration': 'VT-ALL',
#    'serialNo': '36310'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 28.5665,
#      'longitude': 77.103081,
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'origin': {'code': {'iata': 'BOM', 'icao': 'VABB'},
#     'name': 'Mumbai Chhatrapati Shivaji International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 19.08868,
#      'longitude': 72.867912,
#      'region': {'city': 'Mumbai'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': None,
#    'id': 'a9e6245',
#    'number': {'alternative': None, 'default': 'AI101'},
#    'row': 3244670685},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470785665, 'utc': 1470765865},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 23:34'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470765865, 'updated': 1470828439},
#    'real': {'arrival': 1470765720, 'departure': 1470759883},
#    'scheduled': {'arrival': 1470765600, 'departure': 1470758400}}},
#  {'aircraft': {'hex': '8004DE',
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'owner': 'Air India',
#    'registration': 'VT-ALP',
#    'serialNo': '36314'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': 40.639751,
#      'longitude': -73.7789,
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EDT',
#      'abbrName': 'Eastern Daylight Time',
#      'isDst': True,
#      'name': 'America/New_York',
#      'offset': -14400},
#     'visible': True},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 28.5665,
#      'longitude': 77.103081,
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': None,
#    'id': 'a9c3aaf',
#    'number': {'alternative': None, 'default': 'AI101'},
#    'row': 3244670686},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470724825, 'utc': 1470739225},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 06:40'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470739225, 'updated': 1470740168},
#    'real': {'arrival': 1470739140, 'departure': 1470689819},
#    'scheduled': {'arrival': 1470741900, 'departure': 1470687300}}},
#  {'aircraft': {'hex': '8004DE',
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'owner': 'Air India',
#    'registration': 'VT-ALP',
#    'serialNo': '36314'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 28.5665,
#      'longitude': 77.103081,
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'origin': {'code': {'iata': 'BOM', 'icao': 'VABB'},
#     'name': 'Mumbai Chhatrapati Shivaji International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 19.08868,
#      'longitude': 72.867912,
#      'region': {'city': 'Mumbai'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': None,
#    'id': 'a9bb4de',
#    'number': {'alternative': None, 'default': 'AI101'},
#    'row': 3240642434},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470700907, 'utc': 1470681107},
#     'status': {'color': 'yellow',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'yellow',
#    'live': False,
#    'text': 'Landed 00:01'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470681107, 'updated': 1470740168},
#    'real': {'arrival': 1470680940, 'departure': 1470674780},
#    'scheduled': {'arrival': 1470679200, 'departure': 1470672000}}},
#  {'aircraft': {'hex': '8003E4',
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'owner': 'Air India',
#    'registration': 'VT-ALL',
#    'serialNo': '36310'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': 40.639751,
#      'longitude': -73.7789,
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EDT',
#      'abbrName': 'Eastern Daylight Time',
#      'isDst': True,
#      'name': 'America/New_York',
#      'offset': -14400},
#     'visible': True},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': 28.5665,
#      'longitude': 77.103081,
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': False,
#      'name': 'Asia/Kolkata',
#      'offset': 19800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': None,
#    'id': 'a9978b1',
#    'number': {'alternative': None, 'default': 'AI101'},
#    'row': 3240642435},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470637772, 'utc': 1470652172},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 06:29'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470652172, 'updated': 1470653595},
#    'real': {'arrival': 1470652080, 'departure': 1470601973},
#    'scheduled': {'arrival': 1470655500, 'departure': 1470600900}}}]

# %%
get_history_by_tail_number('9V-SMA')[-5:]
# Out:
# [{'aircraft': {'hex': '76CDA1',
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'owner': 'Singapore Airlines',
#    'registration': '9V-SMA',
#    'serialNo': '026'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'KUL', 'icao': 'WMKK'},
#     'name': 'Kuala Lumpur International Airport',
#     'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#      'latitude': 2.745578,
#      'longitude': 101.7099,
#      'region': {'city': 'Kuala Lumpur'}},
#     'timezone': {'abbr': 'MYT',
#      'abbrName': 'Malaysia Time',
#      'isDst': False,
#      'name': 'Asia/Kuala_Lumpur',
#      'offset': 28800},
#     'visible': True},
#    'origin': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': 1.350189,
#      'longitude': 103.9944,
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': 'SGT',
#      'abbrName': 'Singapore Time',
#      'isDst': False,
#      'name': 'Asia/Singapore',
#      'offset': 28800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'SIA118',
#    'codeshare': None,
#    'id': 'aa0602c',
#    'number': {'alternative': 'SQ118', 'default': 'SQ118'},
#    'row': 3249771269},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470857743, 'utc': 1470828943},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 19:35'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470828943, 'updated': 1470830131},
#    'real': {'arrival': 1470828900, 'departure': 1470826633},
#    'scheduled': {'arrival': 1470829500, 'departure': 1470825900}}},
#  {'aircraft': {'hex': '76CDA1',
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'owner': 'Singapore Airlines',
#    'registration': '9V-SMA',
#    'serialNo': '026'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': 1.350189,
#      'longitude': 103.9944,
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': 'SGT',
#      'abbrName': 'Singapore Time',
#      'isDst': False,
#      'name': 'Asia/Singapore',
#      'offset': 28800},
#     'visible': True},
#    'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#     'name': 'Jakarta Soekarno Hatta International Airport',
#     'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#      'latitude': -6.12556,
#      'longitude': 106.6558,
#      'region': {'city': 'Jakarta'}},
#     'timezone': {'abbr': 'WIB',
#      'abbrName': 'Western Indonesian Time',
#      'isDst': False,
#      'name': 'Asia/Jakarta',
#      'offset': 25200},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'SIA963',
#    'codeshare': None,
#    'id': 'a9aef2b',
#    'number': {'alternative': 'SQ963', 'default': 'SQ963'},
#    'row': 3241978602},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470688761, 'utc': 1470659961},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 20:39'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470659961, 'updated': 1470660612},
#    'real': {'arrival': 1470659940, 'departure': 1470655369},
#    'scheduled': {'arrival': 1470660900, 'departure': 1470654300}}},
#  {'aircraft': {'hex': '76CDA1',
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'owner': 'Singapore Airlines',
#    'registration': '9V-SMA',
#    'serialNo': '026'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#     'name': 'Jakarta Soekarno Hatta International Airport',
#     'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#      'latitude': -6.12556,
#      'longitude': 106.6558,
#      'region': {'city': 'Jakarta'}},
#     'timezone': {'abbr': 'WIB',
#      'abbrName': 'Western Indonesian Time',
#      'isDst': False,
#      'name': 'Asia/Jakarta',
#      'offset': 25200},
#     'visible': True},
#    'origin': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': 1.350189,
#      'longitude': 103.9944,
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': 'SGT',
#      'abbrName': 'Singapore Time',
#      'isDst': False,
#      'name': 'Asia/Singapore',
#      'offset': 28800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'SIA962',
#    'codeshare': None,
#    'id': 'a9aa382',
#    'number': {'alternative': 'SQ962', 'default': 'SQ962'},
#    'row': 3241978601},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470675630, 'utc': 1470650430},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 17:00'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470650430, 'updated': 1470650891},
#    'real': {'arrival': 1470650100, 'departure': 1470645448},
#    'scheduled': {'arrival': 1470651000, 'departure': 1470644700}}},
#  {'aircraft': {'hex': '76CDA1',
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'owner': 'Singapore Airlines',
#    'registration': '9V-SMA',
#    'serialNo': '026'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': 1.350189,
#      'longitude': 103.9944,
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': 'SGT',
#      'abbrName': 'Singapore Time',
#      'isDst': False,
#      'name': 'Asia/Singapore',
#      'offset': 28800},
#     'visible': True},
#    'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#     'name': 'Jakarta Soekarno Hatta International Airport',
#     'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#      'latitude': -6.12556,
#      'longitude': 106.6558,
#      'region': {'city': 'Jakarta'}},
#     'timezone': {'abbr': 'WIB',
#      'abbrName': 'Western Indonesian Time',
#      'isDst': False,
#      'name': 'Asia/Jakarta',
#      'offset': 25200},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'SIA957',
#    'codeshare': None,
#    'id': 'a9a4484',
#    'number': {'alternative': 'SQ957', 'default': 'SQ957'},
#    'row': 3241976988},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470663835, 'utc': 1470635035},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 13:43'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470635035, 'updated': 1470635413},
#    'real': {'arrival': 1470634920, 'departure': 1470630327},
#    'scheduled': {'arrival': 1470636300, 'departure': 1470629700}}},
#  {'aircraft': {'hex': '76CDA1',
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'owner': 'Singapore Airlines',
#    'registration': '9V-SMA',
#    'serialNo': '026'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#     'name': 'Jakarta Soekarno Hatta International Airport',
#     'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#      'latitude': -6.12556,
#      'longitude': 106.6558,
#      'region': {'city': 'Jakarta'}},
#     'timezone': {'abbr': 'WIB',
#      'abbrName': 'Western Indonesian Time',
#      'isDst': False,
#      'name': 'Asia/Jakarta',
#      'offset': 25200},
#     'visible': True},
#    'origin': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': 1.350189,
#      'longitude': 103.9944,
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': 'SGT',
#      'abbrName': 'Singapore Time',
#      'isDst': False,
#      'name': 'Asia/Singapore',
#      'offset': 28800},
#     'visible': True},
#    'real': None},
#   'identification': {'callsign': 'SIA956',
#    'codeshare': None,
#    'id': 'a9a10a2',
#    'number': {'alternative': 'SQ956', 'default': 'SQ956'},
#    'row': 3241976987},
#   'status': {'ambiguous': False,
#    'estimated': None,
#    'generic': {'eventTime': {'local': 1470650733, 'utc': 1470625533},
#     'status': {'color': 'green',
#      'diverted': None,
#      'text': 'landed',
#      'type': 'arrival'}},
#    'icon': 'green',
#    'live': False,
#    'text': 'Landed 10:05'},
#   'time': {'estimated': {'arrival': None, 'departure': None},
#    'other': {'eta': 1470625533, 'updated': 1470626231},
#    'real': {'arrival': 1470625500, 'departure': 1470621119},
#    'scheduled': {'arrival': 1470625800, 'departure': 1470619500}}}]

# %%
get_info_by_tail_number('9V-SMA')
# Out:
# [{'age': 'brand new',
#   'aircraft': 'airbus a350-941',
#   'airline': 'singapore airlines',
#   'code': 'sq / sia',
#   'images': ['https://cdn.flightradar24.com/200/5/22056_1470414598_tb.jpg?v=0',
#    'https://cdn.flightradar24.com/200/6/19853_1469390550_tb.jpg?v=0',
#    'https://cdn.flightradar24.com/200/6/97342_1469201026_tb.jpg?v=0'],
#   'mode-s': '76cda1',
#   'operator': 'singapore airlines',
#   'serial-number': '026',
#   'type-code': 'a359'}]
