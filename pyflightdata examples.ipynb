# %% [markdown]
# # pyflightdata examples
#
# This document lists a few examples to show the basic usage of pyflightdata. This does not show all the potential uses of the data we get from the API.
#
# Please note that this is not an official API and we do not endorse or recommend any commercial usage of this API to make large scale mass requests.
#
# Also the API may break from time to time as the pages and their structure change at the underlying websites. For now this is only flightradar24.com but we might add more sites soon.

# %%
from pyflightdata import FlightData

# %%
api=FlightData()

# %%
api.get_countries()[:5]
# Out:
# [{'country': 'Afghanistan',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/afghanistan.gif'},
#  {'country': 'Albania',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/albania.gif'},
#  {'country': 'Algeria',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/algeria.gif'},
#  {'country': 'Angola',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/angola.gif'},
#  {'country': 'Anguilla',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/anguilla.gif'}]

# %%
api.get_airlines()[:5]
# Out:
# [{'airline-code': '9-air-aq-jyh',
#   'callsign': 'AQ / JYH',
#   'fleet-size': '15 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/JYH_logo0.png',
#   'title': '9 Air'},
#  {'airline-code': 'abx-air-gb-abx',
#   'callsign': 'GB / ABX',
#   'fleet-size': '19 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ABX_logo0.png',
#   'title': 'ABX Air'},
#  {'airline-code': 'adria-airways-jp-adr',
#   'callsign': 'JP / ADR',
#   'fleet-size': '22 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ADR_logo0.png',
#   'title': 'Adria Airways'},
#  {'airline-code': 'aegean-airlines-a3-aee',
#   'callsign': 'A3 / AEE',
#   'fleet-size': '47 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/AEE_logo0.png',
#   'title': 'Aegean Airlines'},
#  {'airline-code': 'aer-lingus-ei-ein',
#   'callsign': 'EI / EIN',
#   'fleet-size': '64 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/EIN_logo0.png',
#   'title': 'Aer Lingus'}]

# %%
api.get_airports('India')[10:15]
# Out:
# [{'iata': 'BUP',
#   'lat': '30.2701',
#   'lon': '74.755798',
#   'name': 'Bathinda Airport'},
#  {'iata': 'IXG',
#   'lat': '15.85928',
#   'lon': '74.618294',
#   'name': 'Belgaum Airport'},
#  {'iata': 'BHU',
#   'lat': '21.752199',
#   'lon': '72.185181',
#   'name': 'Bhavnagar Airport'},
#  {'iata': 'BHO',
#   'lat': '23.28746',
#   'lon': '77.337372',
#   'name': 'Bhopal Raja Bhoj Airport'},
#  {'iata': 'BBI',
#   'lat': '20.24436',
#   'lon': '85.81778',
#   'name': 'Bhubaneswar Biju Patnaik International Airport'}]

# %%
#pass the airline-code from get_airlines
api.get_fleet('emirates-ek-uae')
# Out:
# [{'aircraft-regs': ['A6-EDA',
#    'A6-EDB',
#    'A6-EDC',
#    'A6-EDD',
#    'A6-EDE',
#    'A6-EDF',
#    'A6-EDG',
#    'A6-EDH',
#    'A6-EDI',
#    'A6-EDJ',
#    'A6-EDK',
#    'A6-EDL',
#    'A6-EDM',
#    'A6-EDN',
#    'A6-EDO',
#    'A6-EDP',
#    'A6-EDQ',
#    'A6-EDR',
#    'A6-EDS',
#    'A6-EDT',
#    'A6-EDU',
#    'A6-EDV',
#    'A6-EDW',
#    'A6-EDX',
#    'A6-EDY',
#    'A6-EDZ',
#    'A6-EEA',
#    'A6-EEB',
#    'A6-EEC',
#    'A6-EED',
#    'A6-EEE',
#    'A6-EEF',
#    'A6-EEG',
#    'A6-EEH',
#    'A6-EEI',
#    'A6-EEJ',
#    'A6-EEK',
#    'A6-EEL',
#    'A6-EEM',
#    'A6-EEN',
#    'A6-EEO',
#    'A6-EEP',
#    'A6-EEQ',
#    'A6-EER',
#    'A6-EES',
#    'A6-EET',
#    'A6-EEU',
#    'A6-EEV',
#    'A6-EEW',
#    'A6-EEX',
#    'A6-EEY',
#    'A6-EEZ',
#    'A6-EOA',
#    'A6-EOB',
#    'A6-EOC',
#    'A6-EOD',
#    'A6-EOE',
#    'A6-EOF',
#    'A6-EOG',
#    'A6-EOH',
#    'A6-EOI',
#    'A6-EOJ',
#    'A6-EOK',
#    'A6-EOL',
#    'A6-EOM',
#    'A6-EON',
#    'A6-EOO',
#    'A6-EOP',
#    'A6-EOQ',
#    'A6-EOR',
#    'A6-EOS',
#    'A6-EOT',
#    'A6-EOU',
#    'A6-EOV',
#    'A6-EOW',
#    'A6-EOX',
#    'A6-EOY',
#    'A6-EOZ',
#    'A6-EUA',
#    'A6-EUB',
#    'A6-EUC',
#    'A6-EUD',
#    'A6-EUE',
#    'A6-EUF',
#    'A6-EUG',
#    'A6-EUH',
#    'A6-EUI',
#    'A6-EUJ',
#    'A6-EUK',
#    'A6-EUL',
#    'A6-EUM',
#    'A6-EUN',
#    'A6-EUO',
#    'A6-EUP',
#    'A6-EUQ',
#    'A6-EUX',
#    'A6-EUY'],
#   'aircraft-type': 'A388 97',
#   'count': '97'},
#  {'aircraft-regs': ['OO-THD'], 'aircraft-type': 'B744 1', 'count': '1'},
#  {'aircraft-regs': ['A6-EMN',
#    'A6-EMQ',
#    'A6-EMR',
#    'A6-EMT',
#    'A6-EMU',
#    'A6-EMV',
#    'A6-EMX'],
#   'aircraft-type': 'B773 7',
#   'count': '7'},
#  {'aircraft-regs': ['A6-EFD',
#    'A6-EFE',
#    'A6-EFF',
#    'A6-EFG',
#    'A6-EFH',
#    'A6-EFI',
#    'A6-EFJ',
#    'A6-EFK',
#    'A6-EFL',
#    'A6-EFM',
#    'A6-EFN',
#    'A6-EFO',
#    'A6-EFS',
#    'A6-EWA',
#    'A6-EWB',
#    'A6-EWC',
#    'A6-EWD',
#    'A6-EWE',
#    'A6-EWF',
#    'A6-EWG',
#    'A6-EWH',
#    'A6-EWI',
#    'A6-EWJ'],
#   'aircraft-type': 'B77L 23',
#   'count': '23'},
#  {'aircraft-regs': ['A6-EBA',
#    'A6-EBB',
#    'A6-EBC',
#    'A6-EBE',
#    'A6-EBF',
#    'A6-EBG',
#    'A6-EBH',
#    'A6-EBI',
#    'A6-EBJ',
#    'A6-EBK',
#    'A6-EBL',
#    'A6-EBM',
#    'A6-EBN',
#    'A6-EBO',
#    'A6-EBP',
#    'A6-EBQ',
#    'A6-EBR',
#    'A6-EBS',
#    'A6-EBT',
#    'A6-EBU',
#    'A6-EBV',
#    'A6-EBW',
#    'A6-EBX',
#    'A6-EBY',
#    'A6-EBZ',
#    'A6-ECA',
#    'A6-ECB',
#    'A6-ECC',
#    'A6-ECD',
#    'A6-ECE',
#    'A6-ECF',
#    'A6-ECG',
#    'A6-ECH',
#    'A6-ECI',
#    'A6-ECJ',
#    'A6-ECK',
#    'A6-ECL',
#    'A6-ECM',
#    'A6-ECN',
#    'A6-ECO',
#    'A6-ECP',
#    'A6-ECQ',
#    'A6-ECR',
#    'A6-ECS',
#    'A6-ECT',
#    'A6-ECU',
#    'A6-ECV',
#    'A6-ECW',
#    'A6-ECX',
#    'A6-ECY',
#    'A6-ECZ',
#    'A6-EGA',
#    'A6-EGB',
#    'A6-EGC',
#    'A6-EGD',
#    'A6-EGE',
#    'A6-EGF',
#    'A6-EGG',
#    'A6-EGH',
#    'A6-EGI',
#    'A6-EGJ',
#    'A6-EGK',
#    'A6-EGL',
#    'A6-EGM',
#    'A6-EGN',
#    'A6-EGO',
#    'A6-EGP',
#    'A6-EGQ',
#    'A6-EGR',
#    'A6-EGS',
#    'A6-EGT',
#    'A6-EGU',
#    'A6-EGV',
#    'A6-EGW',
#    'A6-EGX',
#    'A6-EGY',
#    'A6-EGZ',
#    'A6-ENA',
#    'A6-ENB',
#    'A6-ENC',
#    'A6-END',
#    'A6-ENE',
#    'A6-ENF',
#    'A6-ENG',
#    'A6-ENH',
#    'A6-ENI',
#    'A6-ENJ',
#    'A6-ENK',
#    'A6-ENL',
#    'A6-ENM',
#    'A6-ENN',
#    'A6-ENO',
#    'A6-ENP',
#    'A6-ENQ',
#    'A6-ENR',
#    'A6-ENS',
#    'A6-ENT',
#    'A6-ENU',
#    'A6-ENV',
#    'A6-ENW',
#    'A6-ENX',
#    'A6-ENY',
#    'A6-ENZ',
#    'A6-EPA',
#    'A6-EPB',
#    'A6-EPC',
#    'A6-EPD',
#    'A6-EPE',
#    'A6-EPF',
#    'A6-EPG',
#    'A6-EPH',
#    'A6-EPI',
#    'A6-EPJ',
#    'A6-EPK',
#    'A6-EPL',
#    'A6-EPM',
#    'A6-EPN',
#    'A6-EPO',
#    'A6-EPP',
#    'A6-EPQ',
#    'A6-EPR',
#    'A6-EPS',
#    'A6-EPT',
#    'A6-EPU',
#    'A6-EPV',
#    'A6-EPW',
#    'A6-EPX',
#    'A6-EPY',
#    'A6-EPZ',
#    'A6-EQA',
#    'A6-EQB',
#    'A6-EQC',
#    'A6-EQD',
#    'A6-EQE',
#    'A6-EQF',
#    'A6-EQG'],
#   'aircraft-type': 'B77W 136',
#   'count': '136'}]

# %%
#pass the airline-code from get_airlines
api.get_fleet('emirates-ek-uae')
# Out:
# [{'aircraft-regs': ['A6-EDA',
#    'A6-EDB',
#    'A6-EDC',
#    'A6-EDD',
#    'A6-EDE',
#    'A6-EDF',
#    'A6-EDG',
#    'A6-EDH',
#    'A6-EDI',
#    'A6-EDJ',
#    'A6-EDK',
#    'A6-EDL',
#    'A6-EDM',
#    'A6-EDN',
#    'A6-EDO',
#    'A6-EDP',
#    'A6-EDQ',
#    'A6-EDR',
#    'A6-EDS',
#    'A6-EDT',
#    'A6-EDU',
#    'A6-EDV',
#    'A6-EDW',
#    'A6-EDX',
#    'A6-EDY',
#    'A6-EDZ',
#    'A6-EEA',
#    'A6-EEB',
#    'A6-EEC',
#    'A6-EED',
#    'A6-EEE',
#    'A6-EEF',
#    'A6-EEG',
#    'A6-EEH',
#    'A6-EEI',
#    'A6-EEJ',
#    'A6-EEK',
#    'A6-EEL',
#    'A6-EEM',
#    'A6-EEN',
#    'A6-EEO',
#    'A6-EEP',
#    'A6-EEQ',
#    'A6-EER',
#    'A6-EES',
#    'A6-EET',
#    'A6-EEU',
#    'A6-EEV',
#    'A6-EEW',
#    'A6-EEX',
#    'A6-EEY',
#    'A6-EEZ',
#    'A6-EOA',
#    'A6-EOB',
#    'A6-EOC',
#    'A6-EOD',
#    'A6-EOE',
#    'A6-EOF',
#    'A6-EOG',
#    'A6-EOH',
#    'A6-EOI',
#    'A6-EOJ',
#    'A6-EOK',
#    'A6-EOL',
#    'A6-EOM',
#    'A6-EON',
#    'A6-EOO',
#    'A6-EOP',
#    'A6-EOQ',
#    'A6-EOR',
#    'A6-EOS',
#    'A6-EOT',
#    'A6-EOU',
#    'A6-EOV',
#    'A6-EOW',
#    'A6-EOX',
#    'A6-EOY',
#    'A6-EOZ',
#    'A6-EUA',
#    'A6-EUB',
#    'A6-EUC',
#    'A6-EUD',
#    'A6-EUE',
#    'A6-EUF',
#    'A6-EUG',
#    'A6-EUH',
#    'A6-EUI',
#    'A6-EUJ',
#    'A6-EUK',
#    'A6-EUL',
#    'A6-EUM',
#    'A6-EUN',
#    'A6-EUO',
#    'A6-EUP',
#    'A6-EUQ',
#    'A6-EUX',
#    'A6-EUY'],
#   'aircraft-type': 'A388 97',
#   'count': '97'},
#  {'aircraft-regs': ['OO-THD'], 'aircraft-type': 'B744 1', 'count': '1'},
#  {'aircraft-regs': ['A6-EMN',
#    'A6-EMQ',
#    'A6-EMR',
#    'A6-EMT',
#    'A6-EMU',
#    'A6-EMV',
#    'A6-EMX'],
#   'aircraft-type': 'B773 7',
#   'count': '7'},
#  {'aircraft-regs': ['A6-EFD',
#    'A6-EFE',
#    'A6-EFF',
#    'A6-EFG',
#    'A6-EFH',
#    'A6-EFI',
#    'A6-EFJ',
#    'A6-EFK',
#    'A6-EFL',
#    'A6-EFM',
#    'A6-EFN',
#    'A6-EFO',
#    'A6-EFS',
#    'A6-EWA',
#    'A6-EWB',
#    'A6-EWC',
#    'A6-EWD',
#    'A6-EWE',
#    'A6-EWF',
#    'A6-EWG',
#    'A6-EWH',
#    'A6-EWI',
#    'A6-EWJ'],
#   'aircraft-type': 'B77L 23',
#   'count': '23'},
#  {'aircraft-regs': ['A6-EBA',
#    'A6-EBB',
#    'A6-EBC',
#    'A6-EBE',
#    'A6-EBF',
#    'A6-EBG',
#    'A6-EBH',
#    'A6-EBI',
#    'A6-EBJ',
#    'A6-EBK',
#    'A6-EBL',
#    'A6-EBM',
#    'A6-EBN',
#    'A6-EBO',
#    'A6-EBP',
#    'A6-EBQ',
#    'A6-EBR',
#    'A6-EBS',
#    'A6-EBT',
#    'A6-EBU',
#    'A6-EBV',
#    'A6-EBW',
#    'A6-EBX',
#    'A6-EBY',
#    'A6-EBZ',
#    'A6-ECA',
#    'A6-ECB',
#    'A6-ECC',
#    'A6-ECD',
#    'A6-ECE',
#    'A6-ECF',
#    'A6-ECG',
#    'A6-ECH',
#    'A6-ECI',
#    'A6-ECJ',
#    'A6-ECK',
#    'A6-ECL',
#    'A6-ECM',
#    'A6-ECN',
#    'A6-ECO',
#    'A6-ECP',
#    'A6-ECQ',
#    'A6-ECR',
#    'A6-ECS',
#    'A6-ECT',
#    'A6-ECU',
#    'A6-ECV',
#    'A6-ECW',
#    'A6-ECX',
#    'A6-ECY',
#    'A6-ECZ',
#    'A6-EGA',
#    'A6-EGB',
#    'A6-EGC',
#    'A6-EGD',
#    'A6-EGE',
#    'A6-EGF',
#    'A6-EGG',
#    'A6-EGH',
#    'A6-EGI',
#    'A6-EGJ',
#    'A6-EGK',
#    'A6-EGL',
#    'A6-EGM',
#    'A6-EGN',
#    'A6-EGO',
#    'A6-EGP',
#    'A6-EGQ',
#    'A6-EGR',
#    'A6-EGS',
#    'A6-EGT',
#    'A6-EGU',
#    'A6-EGV',
#    'A6-EGW',
#    'A6-EGX',
#    'A6-EGY',
#    'A6-EGZ',
#    'A6-ENA',
#    'A6-ENB',
#    'A6-ENC',
#    'A6-END',
#    'A6-ENE',
#    'A6-ENF',
#    'A6-ENG',
#    'A6-ENH',
#    'A6-ENI',
#    'A6-ENJ',
#    'A6-ENK',
#    'A6-ENL',
#    'A6-ENM',
#    'A6-ENN',
#    'A6-ENO',
#    'A6-ENP',
#    'A6-ENQ',
#    'A6-ENR',
#    'A6-ENS',
#    'A6-ENT',
#    'A6-ENU',
#    'A6-ENV',
#    'A6-ENW',
#    'A6-ENX',
#    'A6-ENY',
#    'A6-ENZ',
#    'A6-EPA',
#    'A6-EPB',
#    'A6-EPC',
#    'A6-EPD',
#    'A6-EPE',
#    'A6-EPF',
#    'A6-EPG',
#    'A6-EPH',
#    'A6-EPI',
#    'A6-EPJ',
#    'A6-EPK',
#    'A6-EPL',
#    'A6-EPM',
#    'A6-EPN',
#    'A6-EPO',
#    'A6-EPP',
#    'A6-EPQ',
#    'A6-EPR',
#    'A6-EPS',
#    'A6-EPT',
#    'A6-EPU',
#    'A6-EPV',
#    'A6-EPW',
#    'A6-EPX',
#    'A6-EPY',
#    'A6-EPZ',
#    'A6-EQA',
#    'A6-EQB',
#    'A6-EQC',
#    'A6-EQD',
#    'A6-EQE',
#    'A6-EQF',
#    'A6-EQG'],
#   'aircraft-type': 'B77W 136',
#   'count': '136'}]

# %%
#pass airline-code from get_airlines to see all current live flights
api.get_flights('aegean-airlines-a3-aee')[:10]
# Out:
# [{'aircraft': 'SX-DVR',
#   'aircraft-type': 'A320',
#   'flight': 'A3418',
#   'from': 'Heraklion International Airport, Greece',
#   'to': 'Bordeaux Merignac Airport, France'},
#  {'aircraft': 'SX-DVK',
#   'aircraft-type': 'A320',
#   'flight': 'A3420',
#   'from': 'Heraklion International Airport, Greece',
#   'to': 'Brest Bretagne Airport, France'},
#  {'aircraft': 'SX-DVW',
#   'aircraft-type': 'A320',
#   'flight': 'A3428',
#   'from': 'Heraklion International Airport, Greece',
#   'to': 'Toulouse Blagnac Airport, France'},
#  {'aircraft': 'SX-DVT',
#   'aircraft-type': 'A320',
#   'flight': 'A3452',
#   'from': 'Heraklion International Airport, Greece',
#   'to': 'Paris Charles de Gaulle Airport, France'},
#  {'aircraft': 'SX-DVY',
#   'aircraft-type': 'A320',
#   'flight': 'A3488',
#   'from': 'Rhodes International Airport, Greece',
#   'to': 'Frankfurt Airport, Germany'},
#  {'aircraft': 'SX-DVH',
#   'aircraft-type': 'A320',
#   'flight': 'A3502',
#   'from': 'Thessaloniki International Airport, Greece',
#   'to': 'Munich Airport, Germany'},
#  {'aircraft': 'SX-DNC',
#   'aircraft-type': 'A320',
#   'flight': 'A3510',
#   'from': 'Thessaloniki International Airport, Greece',
#   'to': 'Stuttgart Airport, Germany'},
#  {'aircraft': 'SX-DVQ',
#   'aircraft-type': 'A320',
#   'flight': 'A3613',
#   'from': 'Paris Charles de Gaulle Airport, France',
#   'to': 'Athens Eleftherios Venizelos, Greece'},
#  {'aircraft': 'SX-DVZ',
#   'aircraft-type': 'A321',
#   'flight': 'A3614',
#   'from': 'Athens Eleftherios Venizelos, Greece',
#   'to': 'Paris Charles de Gaulle Airport, France'},
#  {'aircraft': 'SX-DGD',
#   'aircraft-type': 'A320',
#   'flight': 'A3623',
#   'from': 'Brussels Airport, Belgium',
#   'to': 'Athens Eleftherios Venizelos, Greece'}]

# %%
api.get_history_by_flight_number('AI101')[-5:]
# Out:
# [{u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'8004DE',
#    u'model': {u'code': u'B77W', u'text': u'Boeing 777-337(ER)'},
#    u'registration': u'VT-ALP',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India',
#    u'short': u'Air India'},
#   u'airport': {u'destination': {u'code': {u'iata': u'DEL', u'icao': u'VIDP'},
#     u'name': u'Delhi Indira Gandhi International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 28.5665,
#      u'longitude': 77.103081,
#      u'region': {u'city': u'Delhi'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'BOM', u'icao': u'VABB'},
#     u'name': u'Mumbai Chhatrapati Shivaji International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 19.08868,
#      u'longitude': 72.867912,
#      u'region': {u'city': u'Mumbai'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'AIC101',
#    u'codeshare': None,
#    u'id': u'ed85603',
#    u'number': {u'alternative': None, u'default': u'AI101'},
#    u'row': 4403618638},
#   u'owner': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505343780, u'utc': 1505323980},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 23:03'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 5820, u'eta': 1505324082, u'updated': 1505387159},
#    u'real': {u'arrival': 1505323980, u'departure': 1505318176},
#    u'scheduled': {u'arrival': 1505324400, u'departure': 1505316600}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'800584',
#    u'model': {u'code': u'B77W', u'text': u'Boeing 777-337(ER)'},
#    u'registration': u'VT-ALU',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India',
#    u'short': u'Air India'},
#   u'airport': {u'destination': {u'code': {u'iata': u'JFK', u'icao': u'KJFK'},
#     u'name': u'New York John F. Kennedy International Airport',
#     u'position': {u'country': {u'code': u'US', u'name': u'United States'},
#      u'latitude': 40.639751,
#      u'longitude': -73.7789,
#      u'region': {u'city': u'New York'}},
#     u'timezone': {u'abbr': u'EDT',
#      u'abbrName': u'Eastern Daylight Time',
#      u'isDst': True,
#      u'name': u'America/New_York',
#      u'offset': -14400},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'DEL', u'icao': u'VIDP'},
#     u'name': u'Delhi Indira Gandhi International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 28.5665,
#      u'longitude': 77.103081,
#      u'region': {u'city': u'Delhi'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'AIC101',
#    u'codeshare': None,
#    u'id': u'ed63667',
#    u'number': {u'alternative': None, u'default': u'AI101'},
#    u'row': 4403618639},
#   u'owner': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505290260, u'utc': 1505304660},
#     u'status': {u'color': u'red',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'red',
#    u'live': False,
#    u'text': u'Landed 08:11'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 50580, u'eta': 1505304695, u'updated': 1505306545},
#    u'real': {u'arrival': 1505304660, u'departure': 1505254082},
#    u'scheduled': {u'arrival': 1505301900, u'departure': 1505247300}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'8003E3',
#    u'model': {u'code': u'B77W', u'text': u'Boeing 777-337(ER)'},
#    u'registration': u'VT-ALK',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India',
#    u'short': u'Air India'},
#   u'airport': {u'destination': {u'code': {u'iata': u'DEL', u'icao': u'VIDP'},
#     u'name': u'Delhi Indira Gandhi International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 28.5665,
#      u'longitude': 77.103081,
#      u'region': {u'city': u'Delhi'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'BOM', u'icao': u'VABB'},
#     u'name': u'Mumbai Chhatrapati Shivaji International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 19.08868,
#      u'longitude': 72.867912,
#      u'region': {u'city': u'Mumbai'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'AIC101',
#    u'codeshare': None,
#    u'id': u'ed60db2',
#    u'number': {u'alternative': None, u'default': u'AI101'},
#    u'row': 4400286174},
#   u'owner': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505276580, u'utc': 1505256780},
#     u'status': {u'color': u'red',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'red',
#    u'live': False,
#    u'text': u'Landed 04:23'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 5520, u'eta': 1505256844, u'updated': 1505306545},
#    u'real': {u'arrival': 1505256780, u'departure': 1505251254},
#    u'scheduled': {u'arrival': 1505238000, u'departure': 1505230200}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'800462',
#    u'model': {u'code': u'B77W', u'text': u'Boeing 777-337(ER)'},
#    u'registration': u'VT-ALM',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India',
#    u'short': u'Air India'},
#   u'airport': {u'destination': {u'code': {u'iata': u'JFK', u'icao': u'KJFK'},
#     u'name': u'New York John F. Kennedy International Airport',
#     u'position': {u'country': {u'code': u'US', u'name': u'United States'},
#      u'latitude': 40.639751,
#      u'longitude': -73.7789,
#      u'region': {u'city': u'New York'}},
#     u'timezone': {u'abbr': u'EDT',
#      u'abbrName': u'Eastern Daylight Time',
#      u'isDst': True,
#      u'name': u'America/New_York',
#      u'offset': -14400},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'DEL', u'icao': u'VIDP'},
#     u'name': u'Delhi Indira Gandhi International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 28.5665,
#      u'longitude': 77.103081,
#      u'region': {u'city': u'Delhi'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'AIC101',
#    u'codeshare': None,
#    u'id': u'ed2d80b',
#    u'number': {u'alternative': None, u'default': u'AI101'},
#    u'row': 4400286175},
#   u'owner': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505199240, u'utc': 1505213640},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 06:54'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 51360, u'eta': 1505213642, u'updated': 1505215830},
#    u'real': {u'arrival': 1505213640, u'departure': 1505162259},
#    u'scheduled': {u'arrival': 1505215500, u'departure': 1505160900}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'8004DA',
#    u'model': {u'code': u'B77L', u'text': u'Boeing 777-237(LR)'},
#    u'registration': u'VT-ALF',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India',
#    u'short': u'Air India'},
#   u'airport': {u'destination': {u'code': {u'iata': u'DEL', u'icao': u'VIDP'},
#     u'name': u'Delhi Indira Gandhi International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 28.5665,
#      u'longitude': 77.103081,
#      u'region': {u'city': u'Delhi'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'BOM', u'icao': u'VABB'},
#     u'name': u'Mumbai Chhatrapati Shivaji International Airport',
#     u'position': {u'country': {u'code': u'IN', u'name': u'India'},
#      u'latitude': 19.08868,
#      u'longitude': 72.867912,
#      u'region': {u'city': u'Mumbai'}},
#     u'timezone': {u'abbr': u'IST',
#      u'abbrName': u'India Standard Time',
#      u'isDst': False,
#      u'name': u'Asia/Kolkata',
#      u'offset': 19800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'AIC101',
#    u'codeshare': None,
#    u'id': u'ed2275f',
#    u'number': {u'alternative': None, u'default': u'AI101'},
#    u'row': 4425116100},
#   u'owner': {u'code': {u'iata': u'AI', u'icao': u'AIC'},
#    u'name': u'Air India'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505172540, u'utc': 1505152740},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 23:29'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 7140, u'eta': 1505152793, u'updated': 1505215830},
#    u'real': {u'arrival': 1505152740, u'departure': 1505145622},
#    u'scheduled': {u'arrival': 1505152500, u'departure': 1505144700}}}]

# %%
api.get_history_by_tail_number('9V-SMA')[-5:]
# Out:
# [{u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'76CDA1',
#    u'model': {u'code': u'A359', u'text': u'Airbus A350-941'},
#    u'registration': u'9V-SMA',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines',
#    u'short': u'Singapore Airlines'},
#   u'airport': {u'destination': {u'code': {u'iata': u'JNB', u'icao': u'FAOR'},
#     u'name': u'Johannesburg OR Tambo International Airport',
#     u'position': {u'country': {u'code': u'ZA', u'name': u'South Africa'},
#      u'latitude': -26.139099,
#      u'longitude': 28.246,
#      u'region': {u'city': u'Johannesburg'}},
#     u'timezone': {u'abbr': u'SAST',
#      u'abbrName': u'South Africa Standard Time',
#      u'isDst': False,
#      u'name': u'Africa/Johannesburg',
#      u'offset': 7200},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'SIN', u'icao': u'WSSS'},
#     u'name': u'Singapore Changi Airport',
#     u'position': {u'country': {u'code': u'SG', u'name': u'Singapore'},
#      u'latitude': 1.350189,
#      u'longitude': 103.9944,
#      u'region': {u'city': u'Singapore'}},
#     u'timezone': {u'abbr': u'+08',
#      u'abbrName': None,
#      u'isDst': False,
#      u'name': u'Asia/Singapore',
#      u'offset': 28800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'SIA478',
#    u'codeshare': None,
#    u'id': u'ed8c934',
#    u'number': {u'alternative': None, u'default': u'SQ478'},
#    u'row': 4408262078},
#   u'owner': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505369760, u'utc': 1505362560},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 06:16'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 35100, u'eta': 1505362608, u'updated': 1505363469},
#    u'real': {u'arrival': 1505362560, u'departure': 1505327453},
#    u'scheduled': {u'arrival': 1505364900, u'departure': 1505326200}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'76CDA1',
#    u'model': {u'code': u'A359', u'text': u'Airbus A350-941'},
#    u'registration': u'9V-SMA',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines',
#    u'short': u'Singapore Airlines'},
#   u'airport': {u'destination': {u'code': {u'iata': u'SIN', u'icao': u'WSSS'},
#     u'name': u'Singapore Changi Airport',
#     u'position': {u'country': {u'code': u'SG', u'name': u'Singapore'},
#      u'latitude': 1.350189,
#      u'longitude': 103.9944,
#      u'region': {u'city': u'Singapore'}},
#     u'timezone': {u'abbr': u'+08',
#      u'abbrName': None,
#      u'isDst': False,
#      u'name': u'Asia/Singapore',
#      u'offset': 28800},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'MEL', u'icao': u'YMML'},
#     u'name': u'Melbourne Airport',
#     u'position': {u'country': {u'code': u'AU', u'name': u'Australia'},
#      u'latitude': -37.673302,
#      u'longitude': 144.843307,
#      u'region': {u'city': u'Melbourne'}},
#     u'timezone': {u'abbr': u'AEST',
#      u'abbrName': u'Australian Eastern Standard Time',
#      u'isDst': False,
#      u'name': u'Australia/Melbourne',
#      u'offset': 36000},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'SIA208',
#    u'codeshare': None,
#    u'id': u'ed75176',
#    u'number': {u'alternative': None, u'default': u'SQ208'},
#    u'row': 4404107431},
#   u'owner': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505347754, u'utc': 1505318954},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 00:09'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 26880, u'eta': 1505318954, u'updated': 1505319475},
#    u'real': {u'arrival': 1505318954, u'departure': 1505292074},
#    u'scheduled': {u'arrival': 1505319300, u'departure': 1505291100}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'76CDA1',
#    u'model': {u'code': u'A359', u'text': u'Airbus A350-941'},
#    u'registration': u'9V-SMA',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines',
#    u'short': u'Singapore Airlines'},
#   u'airport': {u'destination': {u'code': {u'iata': u'MEL', u'icao': u'YMML'},
#     u'name': u'Melbourne Airport',
#     u'position': {u'country': {u'code': u'AU', u'name': u'Australia'},
#      u'latitude': -37.673302,
#      u'longitude': 144.843307,
#      u'region': {u'city': u'Melbourne'}},
#     u'timezone': {u'abbr': u'AEST',
#      u'abbrName': u'Australian Eastern Standard Time',
#      u'isDst': False,
#      u'name': u'Australia/Melbourne',
#      u'offset': 36000},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'SIN', u'icao': u'WSSS'},
#     u'name': u'Singapore Changi Airport',
#     u'position': {u'country': {u'code': u'SG', u'name': u'Singapore'},
#      u'latitude': 1.350189,
#      u'longitude': 103.9944,
#      u'region': {u'city': u'Singapore'}},
#     u'timezone': {u'abbr': u'+08',
#      u'abbrName': None,
#      u'isDst': False,
#      u'name': u'Asia/Singapore',
#      u'offset': 28800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'SIA207',
#    u'codeshare': None,
#    u'id': u'ed67ed2',
#    u'number': {u'alternative': None, u'default': u'SQ207'},
#    u'row': 4404936370},
#   u'owner': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505321580, u'utc': 1505285580},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 16:53'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 23880, u'eta': 1505285684, u'updated': 1505286294},
#    u'real': {u'arrival': 1505285580, u'departure': 1505261714},
#    u'scheduled': {u'arrival': 1505286600, u'departure': 1505259900}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'76CDA1',
#    u'model': {u'code': u'A359', u'text': u'Airbus A350-941'},
#    u'registration': u'9V-SMA',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines',
#    u'short': u'Singapore Airlines'},
#   u'airport': {u'destination': {u'code': {u'iata': u'SIN', u'icao': u'WSSS'},
#     u'name': u'Singapore Changi Airport',
#     u'position': {u'country': {u'code': u'SG', u'name': u'Singapore'},
#      u'latitude': 1.350189,
#      u'longitude': 103.9944,
#      u'region': {u'city': u'Singapore'}},
#     u'timezone': {u'abbr': u'+08',
#      u'abbrName': None,
#      u'isDst': False,
#      u'name': u'Asia/Singapore',
#      u'offset': 28800},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'FCO', u'icao': u'LIRF'},
#     u'name': u'Rome Leonardo da Vinci Fiumicino Airport',
#     u'position': {u'country': {u'code': u'IT', u'name': u'Italy'},
#      u'latitude': 41.80447,
#      u'longitude': 12.25079,
#      u'region': {u'city': u'Rome'}},
#     u'timezone': {u'abbr': u'CEST',
#      u'abbrName': u'Central European Summer Time',
#      u'isDst': True,
#      u'name': u'Europe/Rome',
#      u'offset': 7200},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'SIA365',
#    u'codeshare': None,
#    u'id': u'ed45e1b',
#    u'number': {u'alternative': None, u'default': u'SQ365'},
#    u'row': 4400422943},
#   u'owner': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505281260, u'utc': 1505252460},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 05:41'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 40380, u'eta': 1505252570, u'updated': 1505253058},
#    u'real': {u'arrival': 1505252460, u'departure': 1505212086},
#    u'scheduled': {u'arrival': 1505253600, u'departure': 1505210400}}},
#  {u'aircraft': {u'age': {u'availability': True},
#    u'availability': {u'age': True, u'serialNo': True},
#    u'hex': u'76CDA1',
#    u'model': {u'code': u'A359', u'text': u'Airbus A350-941'},
#    u'registration': u'9V-SMA',
#    u'restricted': False,
#    u'serialNo': None},
#   u'airline': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines',
#    u'short': u'Singapore Airlines'},
#   u'airport': {u'destination': {u'code': {u'iata': u'FCO', u'icao': u'LIRF'},
#     u'name': u'Rome Leonardo da Vinci Fiumicino Airport',
#     u'position': {u'country': {u'code': u'IT', u'name': u'Italy'},
#      u'latitude': 41.80447,
#      u'longitude': 12.25079,
#      u'region': {u'city': u'Rome'}},
#     u'timezone': {u'abbr': u'CEST',
#      u'abbrName': u'Central European Summer Time',
#      u'isDst': True,
#      u'name': u'Europe/Rome',
#      u'offset': 7200},
#     u'visible': True},
#    u'origin': {u'code': {u'iata': u'SIN', u'icao': u'WSSS'},
#     u'name': u'Singapore Changi Airport',
#     u'position': {u'country': {u'code': u'SG', u'name': u'Singapore'},
#      u'latitude': 1.350189,
#      u'longitude': 103.9944,
#      u'region': {u'city': u'Singapore'}},
#     u'timezone': {u'abbr': u'+08',
#      u'abbrName': None,
#      u'isDst': False,
#      u'name': u'Asia/Singapore',
#      u'offset': 28800},
#     u'visible': True},
#    u'real': None},
#   u'identification': {u'callsign': u'SIA366',
#    u'codeshare': None,
#    u'id': u'ed2751f',
#    u'number': {u'alternative': None, u'default': u'SQ366'},
#    u'row': 4394156331},
#   u'owner': {u'code': {u'iata': u'SQ', u'icao': u'SIA'},
#    u'name': u'Singapore Airlines'},
#   u'status': {u'ambiguous': False,
#    u'estimated': None,
#    u'generic': {u'eventTime': {u'local': 1505203500, u'utc': 1505196300},
#     u'status': {u'color': u'green',
#      u'diverted': None,
#      u'text': u'landed',
#      u'type': u'arrival'}},
#    u'icon': u'green',
#    u'live': False,
#    u'text': u'Landed 08:05'},
#   u'time': {u'estimated': {u'arrival': None, u'departure': None},
#    u'other': {u'duration': 43800, u'eta': 1505196346, u'updated': 1505196817},
#    u'real': {u'arrival': 1505196300, u'departure': 1505152499},
#    u'scheduled': {u'arrival': 1505196300, u'departure': 1505151000}}}]

# %%
api.get_info_by_tail_number('9V-SMA')
# Out:
# [{'age': '',
#   'aircraft': 'airbus a350-941',
#   'airline': 'singapore airlines',
#   'code': 'sq / sia',
#   'images': [],
#   'mode-s': '76cda1',
#   'operator': 'singapore airlines',
#   'serial-number': '',
#   'type-code': 'a359'}]
