# %% [markdown]
# # pyflightdata examples
#
# This document lists a few examples to show the basic usage of pyflightdata. This does not show all the potential uses of the data we get from the API.
#
# Please note that this is not an official API and we do not endorse or recommend any commercial usage of this API to make large scale mass requests.
#
# Also the API may break from time to time as the pages and their structure change at the underlying websites. For now this is only flightradar24.com but we might add more sites soon.

# %%
from pyflightdata import FlightData

# %%
api=FlightData()

# %%
api.get_countries()[:5]
# Out:
# [{'country': 'Afghanistan',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/afghanistan.gif'},
#  {'country': 'Albania',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/albania.gif'},
#  {'country': 'Algeria',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/algeria.gif'},
#  {'country': 'Angola',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/angola.gif'},
#  {'country': 'Anguilla',
#   'img': 'https://www.flightradar24.com/static/images/data/flags-small/anguilla.gif'}]

# %%
api.get_airlines()[:5]
# Out:
# [{'airline-code': '9-air-aq-jyh',
#   'callsign': 'AQ / JYH',
#   'fleet-size': '15 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/JYH_logo0.png',
#   'title': '9 Air'},
#  {'airline-code': 'abx-air-gb-abx',
#   'callsign': 'GB / ABX',
#   'fleet-size': '19 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ABX_logo0.png',
#   'title': 'ABX Air'},
#  {'airline-code': 'adria-airways-jp-adr',
#   'callsign': 'JP / ADR',
#   'fleet-size': '12 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/ADR_logo0.png',
#   'title': 'Adria Airways'},
#  {'airline-code': 'advanced-air-an-wsn',
#   'callsign': 'AN / WSN',
#   'fleet-size': '1 aircraft',
#   'title': 'Advanced Air'},
#  {'airline-code': 'aegean-airlines-a3-aee',
#   'callsign': 'A3 / AEE',
#   'fleet-size': '47 aircraft',
#   'img': 'https://www.flightradar24.com/static/images/data/operators/AEE_logo0.png',
#   'title': 'Aegean Airlines'}]

# %%
api.get_airports('India')[10:15]
# Out:
# [{'iata': 'IXG',
#   'lat': '15.85928',
#   'lon': '74.618294',
#   'name': 'Belgaum Airport'},
#  {'iata': 'BLR',
#   'lat': '13.198889',
#   'lon': '77.705559',
#   'name': 'Bengaluru Kempegowda International Airport'},
#  {'iata': 'BHU',
#   'lat': '21.752199',
#   'lon': '72.185181',
#   'name': 'Bhavnagar Airport'},
#  {'iata': 'BHO',
#   'lat': '23.28746',
#   'lon': '77.337372',
#   'name': 'Bhopal Raja Bhoj Airport'},
#  {'iata': 'BBI',
#   'lat': '20.24436',
#   'lon': '85.81778',
#   'name': 'Bhubaneswar Biju Patnaik International Airport'}]

# %%
#pass the airline-code from get_airlines
api.get_fleet('emirates-ek-uae')
# Out:
# [{'aircraft-regs': ['A6-EDA',
#    'A6-EDB',
#    'A6-EDC',
#    'A6-EDD',
#    'A6-EDE',
#    'A6-EDF',
#    'A6-EDG',
#    'A6-EDH',
#    'A6-EDI',
#    'A6-EDJ',
#    'A6-EDK',
#    'A6-EDL',
#    'A6-EDM',
#    'A6-EDN',
#    'A6-EDO',
#    'A6-EDP',
#    'A6-EDQ',
#    'A6-EDR',
#    'A6-EDS',
#    'A6-EDT',
#    'A6-EDU',
#    'A6-EDV',
#    'A6-EDW',
#    'A6-EDX',
#    'A6-EDY',
#    'A6-EDZ',
#    'A6-EEA',
#    'A6-EEB',
#    'A6-EEC',
#    'A6-EED',
#    'A6-EEE',
#    'A6-EEF',
#    'A6-EEG',
#    'A6-EEH',
#    'A6-EEI',
#    'A6-EEJ',
#    'A6-EEK',
#    'A6-EEL',
#    'A6-EEM',
#    'A6-EEN',
#    'A6-EEO',
#    'A6-EEP',
#    'A6-EEQ',
#    'A6-EER',
#    'A6-EES',
#    'A6-EET',
#    'A6-EEU',
#    'A6-EEV',
#    'A6-EEW',
#    'A6-EEX',
#    'A6-EEY',
#    'A6-EEZ',
#    'A6-EOA',
#    'A6-EOB',
#    'A6-EOC',
#    'A6-EOD',
#    'A6-EOE',
#    'A6-EOF',
#    'A6-EOG',
#    'A6-EOH',
#    'A6-EOI',
#    'A6-EOJ',
#    'A6-EOK',
#    'A6-EOL',
#    'A6-EOM',
#    'A6-EON',
#    'A6-EOO',
#    'A6-EOP',
#    'A6-EOQ',
#    'A6-EOR',
#    'A6-EOS',
#    'A6-EOT',
#    'A6-EOU',
#    'A6-EOV',
#    'A6-EOW',
#    'A6-EOX',
#    'A6-EOY',
#    'A6-EOZ',
#    'A6-EUA',
#    'A6-EUB',
#    'A6-EUC',
#    'A6-EUD',
#    'A6-EUE',
#    'A6-EUF',
#    'A6-EUG',
#    'A6-EUH',
#    'A6-EUI',
#    'A6-EUJ',
#    'A6-EUK',
#    'A6-EUL',
#    'A6-EUM',
#    'A6-EUN',
#    'A6-EUO',
#    'A6-EUP',
#    'A6-EUQ',
#    'A6-EUR',
#    'A6-EUS',
#    'A6-EUT',
#    'A6-EUV',
#    'A6-EUX',
#    'A6-EUY',
#    'A6-EUZ'],
#   'aircraft-type': 'A388 102',
#   'count': '102'},
#  {'aircraft-regs': ['OO-THD'], 'aircraft-type': 'B744 1', 'count': '1'},
#  {'aircraft-regs': ['A6-EMN',
#    'A6-EMQ',
#    'A6-EMR',
#    'A6-EMT',
#    'A6-EMV',
#    'A6-EMX'],
#   'aircraft-type': 'B773 6',
#   'count': '6'},
#  {'aircraft-regs': ['A6-EFD',
#    'A6-EFE',
#    'A6-EFF',
#    'A6-EFG',
#    'A6-EFH',
#    'A6-EFI',
#    'A6-EFJ',
#    'A6-EFK',
#    'A6-EFL',
#    'A6-EFM',
#    'A6-EFN',
#    'A6-EFO',
#    'A6-EFS',
#    'A6-EWA',
#    'A6-EWB',
#    'A6-EWC',
#    'A6-EWD',
#    'A6-EWE',
#    'A6-EWF',
#    'A6-EWG',
#    'A6-EWH',
#    'A6-EWI',
#    'A6-EWJ'],
#   'aircraft-type': 'B77L 23',
#   'count': '23'},
#  {'aircraft-regs': ['A6-EBA',
#    'A6-EBB',
#    'A6-EBC',
#    'A6-EBE',
#    'A6-EBF',
#    'A6-EBG',
#    'A6-EBH',
#    'A6-EBI',
#    'A6-EBJ',
#    'A6-EBK',
#    'A6-EBL',
#    'A6-EBM',
#    'A6-EBN',
#    'A6-EBO',
#    'A6-EBP',
#    'A6-EBQ',
#    'A6-EBR',
#    'A6-EBS',
#    'A6-EBT',
#    'A6-EBU',
#    'A6-EBV',
#    'A6-EBW',
#    'A6-EBX',
#    'A6-EBY',
#    'A6-EBZ',
#    'A6-ECA',
#    'A6-ECB',
#    'A6-ECC',
#    'A6-ECD',
#    'A6-ECE',
#    'A6-ECF',
#    'A6-ECG',
#    'A6-ECH',
#    'A6-ECI',
#    'A6-ECJ',
#    'A6-ECK',
#    'A6-ECL',
#    'A6-ECM',
#    'A6-ECN',
#    'A6-ECO',
#    'A6-ECP',
#    'A6-ECQ',
#    'A6-ECR',
#    'A6-ECS',
#    'A6-ECT',
#    'A6-ECU',
#    'A6-ECV',
#    'A6-ECW',
#    'A6-ECX',
#    'A6-ECY',
#    'A6-ECZ',
#    'A6-EGA',
#    'A6-EGB',
#    'A6-EGC',
#    'A6-EGD',
#    'A6-EGE',
#    'A6-EGF',
#    'A6-EGG',
#    'A6-EGH',
#    'A6-EGI',
#    'A6-EGJ',
#    'A6-EGK',
#    'A6-EGL',
#    'A6-EGM',
#    'A6-EGN',
#    'A6-EGO',
#    'A6-EGP',
#    'A6-EGQ',
#    'A6-EGR',
#    'A6-EGS',
#    'A6-EGT',
#    'A6-EGU',
#    'A6-EGV',
#    'A6-EGW',
#    'A6-EGX',
#    'A6-EGY',
#    'A6-EGZ',
#    'A6-ENA',
#    'A6-ENB',
#    'A6-ENC',
#    'A6-END',
#    'A6-ENE',
#    'A6-ENF',
#    'A6-ENG',
#    'A6-ENH',
#    'A6-ENI',
#    'A6-ENJ',
#    'A6-ENK',
#    'A6-ENL',
#    'A6-ENM',
#    'A6-ENN',
#    'A6-ENO',
#    'A6-ENP',
#    'A6-ENQ',
#    'A6-ENR',
#    'A6-ENS',
#    'A6-ENT',
#    'A6-ENU',
#    'A6-ENV',
#    'A6-ENW',
#    'A6-ENX',
#    'A6-ENY',
#    'A6-ENZ',
#    'A6-EPA',
#    'A6-EPB',
#    'A6-EPC',
#    'A6-EPD',
#    'A6-EPE',
#    'A6-EPF',
#    'A6-EPG',
#    'A6-EPH',
#    'A6-EPI',
#    'A6-EPJ',
#    'A6-EPK',
#    'A6-EPL',
#    'A6-EPM',
#    'A6-EPN',
#    'A6-EPO',
#    'A6-EPP',
#    'A6-EPQ',
#    'A6-EPR',
#    'A6-EPS',
#    'A6-EPT',
#    'A6-EPU',
#    'A6-EPV',
#    'A6-EPW',
#    'A6-EPX',
#    'A6-EPY',
#    'A6-EPZ',
#    'A6-EQA',
#    'A6-EQB',
#    'A6-EQC',
#    'A6-EQD',
#    'A6-EQE',
#    'A6-EQF',
#    'A6-EQG',
#    'A6-EQH',
#    'A6-EQI',
#    'A6-EQJ'],
#   'aircraft-type': 'B77W 139',
#   'count': '139'}]

# %%
#pass airline-code from get_airlines to see all current live flights
api.get_flights('aegean-airlines-a3-aee')[:10]
# Out:
# []

# %%
api.get_history_by_flight_number('AI101')[-5:]
# Out:
# [{'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'registration': 'VT-ALO',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'},
#    'name': 'Air India',
#    'short': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': '40.639751',
#      'longitude': '-73.7789',
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EST',
#      'abbrName': 'Eastern Standard Time',
#      'isDst': 'False',
#      'name': 'America/New_York',
#      'offset': '-18000'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '28.5665',
#      'longitude': '77.103081',
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'AI101'}},
#   'owner': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514879939', 'utc': '1514897939'},
#     'status': {'color': 'red',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 07:58'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '53100',
#     'eta': '1514897939',
#     'updated': '1514882515'},
#    'real': {'arrival': '1514897939', 'departure': '1514844865'},
#    'scheduled': {'arrival': '1514892900', 'departure': '1514837100'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'registration': 'VT-ALL',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'},
#    'name': 'Air India',
#    'short': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '28.5665',
#      'longitude': '77.103081',
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'BOM', 'icao': 'VABB'},
#     'name': 'Mumbai Chhatrapati Shivaji International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '19.08868',
#      'longitude': '72.867912',
#      'region': {'city': 'Mumbai'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'AI101'}},
#   'owner': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514849649', 'utc': '1514829849'},
#     'status': {'color': 'yellow',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 23:34'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '8220', 'eta': '1514829849', 'updated': '1514829963'},
#    'real': {'arrival': '1514829849', 'departure': '1514821633'},
#    'scheduled': {'arrival': '1514828700', 'departure': '1514820600'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'registration': 'VT-ALN',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'},
#    'name': 'Air India',
#    'short': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': '40.639751',
#      'longitude': '-73.7789',
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EST',
#      'abbrName': 'Eastern Standard Time',
#      'isDst': 'False',
#      'name': 'America/New_York',
#      'offset': '-18000'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '28.5665',
#      'longitude': '77.103081',
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'AI101'}},
#   'owner': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514787514', 'utc': '1514805514'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 06:18'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '52080',
#     'eta': '1514805514',
#     'updated': '1514791746'},
#    'real': {'arrival': '1514805514', 'departure': '1514753420'},
#    'scheduled': {'arrival': '1514806500', 'departure': '1514750700'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'registration': 'VT-ALO',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'},
#    'name': 'Air India',
#    'short': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '28.5665',
#      'longitude': '77.103081',
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'BOM', 'icao': 'VABB'},
#     'name': 'Mumbai Chhatrapati Shivaji International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '19.08868',
#      'longitude': '72.867912',
#      'region': {'city': 'Mumbai'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'AI101'}},
#   'owner': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514763203', 'utc': '1514743403'},
#     'status': {'color': 'yellow',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 23:33'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '6360', 'eta': '1514743403', 'updated': '1514743481'},
#    'real': {'arrival': '1514743403', 'departure': '1514737014'},
#    'scheduled': {'arrival': '1514742300', 'departure': '1514734200'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'B77W', 'text': 'Boeing 777-337(ER)'},
#    'registration': 'VT-ALL',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'AI', 'icao': 'AIC'},
#    'name': 'Air India',
#    'short': 'Air India'},
#   'airport': {'destination': {'code': {'iata': 'JFK', 'icao': 'KJFK'},
#     'name': 'New York John F. Kennedy International Airport',
#     'position': {'country': {'code': 'US', 'name': 'United States'},
#      'latitude': '40.639751',
#      'longitude': '-73.7789',
#      'region': {'city': 'New York'}},
#     'timezone': {'abbr': 'EST',
#      'abbrName': 'Eastern Standard Time',
#      'isDst': 'False',
#      'name': 'America/New_York',
#      'offset': '-18000'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'DEL', 'icao': 'VIDP'},
#     'name': 'Delhi Indira Gandhi International Airport',
#     'position': {'country': {'code': 'IN', 'name': 'India'},
#      'latitude': '28.5665',
#      'longitude': '77.103081',
#      'region': {'city': 'Delhi'}},
#     'timezone': {'abbr': 'IST',
#      'abbrName': 'India Standard Time',
#      'isDst': 'False',
#      'name': 'Asia/Kolkata',
#      'offset': '19800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'AIC101',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'AI101'}},
#   'owner': {'code': {'iata': 'AI', 'icao': 'AIC'}, 'name': 'Air India'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514699759', 'utc': '1514717759'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 05:55'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '51840',
#     'eta': '1514717759',
#     'updated': '1514700941'},
#    'real': {'arrival': '1514717759', 'departure': '1514665942'},
#    'scheduled': {'arrival': '1514720100', 'departure': '1514664300'}}}]

# %%
api.get_history_by_tail_number('9V-SMA')[-5:]
# Out:
# [{'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'registration': '9V-SMA',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines',
#    'short': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': '1.350189',
#      'longitude': '103.9944',
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': '+08',
#      'abbrName': 'None',
#      'isDst': 'False',
#      'name': 'Asia/Singapore',
#      'offset': '28800'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'BNE', 'icao': 'YBBN'},
#     'name': 'Brisbane Airport',
#     'position': {'country': {'code': 'AU', 'name': 'Australia'},
#      'latitude': '-27.3841',
#      'longitude': '153.117493',
#      'region': {'city': 'Brisbane'}},
#     'timezone': {'abbr': 'AEST',
#      'abbrName': 'Australian Eastern Standard Time',
#      'isDst': 'False',
#      'name': 'Australia/Brisbane',
#      'offset': '36000'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'SIA246',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'SQ246'}},
#   'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514955292', 'utc': '1514926492'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 04:54'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '26160',
#     'eta': '1514926492',
#     'updated': '1514926942'},
#    'real': {'arrival': '1514926492', 'departure': '1514900349'},
#    'scheduled': {'arrival': '1514928900', 'departure': '1514900100'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'registration': '9V-SMA',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines',
#    'short': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'BNE', 'icao': 'YBBN'},
#     'name': 'Brisbane Airport',
#     'position': {'country': {'code': 'AU', 'name': 'Australia'},
#      'latitude': '-27.3841',
#      'longitude': '153.117493',
#      'region': {'city': 'Brisbane'}},
#     'timezone': {'abbr': 'AEST',
#      'abbrName': 'Australian Eastern Standard Time',
#      'isDst': 'False',
#      'name': 'Australia/Brisbane',
#      'offset': '36000'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': '1.350189',
#      'longitude': '103.9944',
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': '+08',
#      'abbrName': 'None',
#      'isDst': 'False',
#      'name': 'Asia/Singapore',
#      'offset': '28800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'SIA245',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'SQ245'}},
#   'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514920984', 'utc': '1514884984'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 19:23'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '26040',
#     'eta': '1514884984',
#     'updated': '1514859623'},
#    'real': {'arrival': '1514884984', 'departure': '1514858922'},
#    'scheduled': {'arrival': '1514886300', 'departure': '1514857500'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'registration': '9V-SMA',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines',
#    'short': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': '1.350189',
#      'longitude': '103.9944',
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': '+08',
#      'abbrName': 'None',
#      'isDst': 'False',
#      'name': 'Asia/Singapore',
#      'offset': '28800'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'JNB', 'icao': 'FAOR'},
#     'name': 'Johannesburg OR Tambo International Airport',
#     'position': {'country': {'code': 'ZA', 'name': 'South Africa'},
#      'latitude': '-26.139099',
#      'longitude': '28.246',
#      'region': {'city': 'Johannesburg'}},
#     'timezone': {'abbr': 'SAST',
#      'abbrName': 'South Africa Standard Time',
#      'isDst': 'False',
#      'name': 'Africa/Johannesburg',
#      'offset': '7200'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'SIA479',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'SQ479'}},
#   'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514871705', 'utc': '1514842905'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 05:41'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '35100',
#     'eta': '1514842905',
#     'updated': '1514840183'},
#    'real': {'arrival': '1514842905', 'departure': '1514807792'},
#    'scheduled': {'arrival': '1514844600', 'departure': '1514807100'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'registration': '9V-SMA',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines',
#    'short': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'JNB', 'icao': 'FAOR'},
#     'name': 'Johannesburg OR Tambo International Airport',
#     'position': {'country': {'code': 'ZA', 'name': 'South Africa'},
#      'latitude': '-26.139099',
#      'longitude': '28.246',
#      'region': {'city': 'Johannesburg'}},
#     'timezone': {'abbr': 'SAST',
#      'abbrName': 'South Africa Standard Time',
#      'isDst': 'False',
#      'name': 'Africa/Johannesburg',
#      'offset': '7200'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': '1.350189',
#      'longitude': '103.9944',
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': '+08',
#      'abbrName': 'None',
#      'isDst': 'False',
#      'name': 'Asia/Singapore',
#      'offset': '28800'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'SIA478',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'SQ478'}},
#   'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514788759', 'utc': '1514781559'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 06:39'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '36360',
#     'eta': '1514781559',
#     'updated': '1514781205'},
#    'real': {'arrival': '1514781559', 'departure': '1514745218'},
#    'scheduled': {'arrival': '1514782200', 'departure': '1514743800'}}},
#  {'aircraft': {'age': {'availability': 'True'},
#    'availability': {'age': 'True', 'serialNo': 'True'},
#    'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#    'registration': '9V-SMA',
#    'restricted': 'False',
#    'serialNo': 'None'},
#   'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines',
#    'short': 'Singapore Airlines'},
#   'airport': {'destination': {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#     'name': 'Singapore Changi Airport',
#     'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#      'latitude': '1.350189',
#      'longitude': '103.9944',
#      'region': {'city': 'Singapore'}},
#     'timezone': {'abbr': '+08',
#      'abbrName': 'None',
#      'isDst': 'False',
#      'name': 'Asia/Singapore',
#      'offset': '28800'},
#     'visible': 'True'},
#    'origin': {'code': {'iata': 'MEL', 'icao': 'YMML'},
#     'name': 'Melbourne Airport',
#     'position': {'country': {'code': 'AU', 'name': 'Australia'},
#      'latitude': '-37.673302',
#      'longitude': '144.843307',
#      'region': {'city': 'Melbourne'}},
#     'timezone': {'abbr': 'AEDT',
#      'abbrName': 'Australian Eastern Daylight Time',
#      'isDst': 'True',
#      'name': 'Australia/Melbourne',
#      'offset': '39600'},
#     'visible': 'True'},
#    'real': 'None'},
#   'identification': {'callsign': 'SIA208',
#    'codeshare': 'None',
#    'number': {'alternative': 'None', 'default': 'SQ208'}},
#   'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#    'name': 'Singapore Airlines'},
#   'status': {'ambiguous': 'False',
#    'estimated': 'None',
#    'generic': {'eventTime': {'local': '1514764802', 'utc': '1514736002'},
#     'status': {'color': 'green',
#      'diverted': 'None',
#      'text': 'landed',
#      'type': 'arrival'}},
#    'live': 'False',
#    'text': 'Landed 00:00'},
#   'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#    'other': {'duration': '26400',
#     'eta': '1514736002',
#     'updated': '1514732034'},
#    'real': {'arrival': '1514736002', 'departure': '1514709621'},
#    'scheduled': {'arrival': '1514736300', 'departure': '1514708700'}}}]

# %%
api.get_info_by_tail_number('9V-SMA')
# Out:
# [{'age': '',
#   'aircraft': 'airbus a350-941',
#   'airline': 'singapore airlines',
#   'code': 'sq / sia',
#   'images': [],
#   'mode-s': '76cda1',
#   'operator': 'singapore airlines',
#   'serial-number': '',
#   'type-code': 'a359'}]

# %%
api.get_airport_arrivals('sin')
# Out:
# [{'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-233'},
#     'registration': '9V-SLI',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': '36',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'MAA', 'icao': 'VOMM'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '4'},
#      'name': 'Chennai International Airport',
#      'position': {'country': {'code': 'IN', 'name': 'India'},
#       'latitude': '12.99441',
#       'longitude': '80.180511',
#       'region': {'city': 'Chennai'}},
#      'timezone': {'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Kolkata',
#       'offset': '19800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SLK435',
#     'number': {'alternative': 'None', 'default': 'MI435'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515342609', 'utc': '1515313809'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'landed',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Landed 16:30'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': '14340', 'eta': '1515313809'},
#     'real': {'arrival': '1515313809', 'departure': '1515299493'},
#     'scheduled': {'arrival': '1515314700', 'departure': '1515299400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A332', 'text': 'Airbus A330-202'},
#     'registration': 'VH-EBQ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'QF', 'icao': 'QFA'},
#     'name': 'Qantas',
#     'short': 'Qantas'},
#    'airport': {'destination': {'info': {'baggage': '18',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'SYD', 'icao': 'YSSY'},
#      'info': {'baggage': 'None', 'gate': '10', 'terminal': '1'},
#      'name': 'Sydney Kingsford Smith Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-33.946098',
#       'longitude': '151.1772',
#       'region': {'city': 'Sydney'}},
#      'timezone': {'abbr': 'AEDT',
#       'abbrName': 'Australian Eastern Daylight Time',
#       'isDst': 'True',
#       'name': 'Australia/Sydney',
#       'offset': '39600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'QFA81',
#     'number': {'alternative': 'None', 'default': 'QF81'}},
#    'owner': {'code': {'iata': 'QF', 'icao': 'QFA'}, 'name': 'Qantas'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344639', 'utc': '1515315839'},
#      'status': {'color': 'yellow',
#       'diverted': 'None',
#       'text': 'delayed',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Delayed 17:03'},
#    'time': {'estimated': {'arrival': '1515315839', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315839'},
#     'real': {'arrival': 'None', 'departure': '1515288391'},
#     'scheduled': {'arrival': '1515314700', 'departure': '1515285300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#     'registration': 'B-6292',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'CZ', 'icao': 'CSN'},
#     'name': 'China Southern Airlines',
#     'short': 'China Southern Airlines'},
#    'airport': {'destination': {'info': {'baggage': '23',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CAN', 'icao': 'ZGGG'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Guangzhou Baiyun International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '23.392429',
#       'longitude': '113.298698',
#       'region': {'city': 'Guangzhou'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'CSN3039',
#     'number': {'alternative': 'None', 'default': 'CZ3039'}},
#    'owner': {'code': {'iata': 'CZ', 'icao': 'CSN'},
#     'name': 'China Southern Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344223', 'utc': '1515315423'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:57'},
#    'time': {'estimated': {'arrival': '1515315423', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315423'},
#     'real': {'arrival': 'None', 'departure': '1515301525'},
#     'scheduled': {'arrival': '1515315000', 'departure': '1515300000'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B788', 'text': 'Boeing 787-8 Dreamliner'},
#     'registration': 'VH-VKD',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JQ', 'icao': 'JST'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Airways'},
#    'airport': {'destination': {'info': {'baggage': '17',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'MEL', 'icao': 'YMML'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Melbourne Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-37.673302',
#       'longitude': '144.843307',
#       'region': {'city': 'Melbourne'}},
#      'timezone': {'abbr': 'AEDT',
#       'abbrName': 'Australian Eastern Daylight Time',
#       'isDst': 'True',
#       'name': 'Australia/Melbourne',
#       'offset': '39600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'JST7',
#     'number': {'alternative': 'None', 'default': 'JQ7'}},
#    'owner': {'code': {'iata': 'JQ', 'icao': 'JST'}, 'name': 'Jetstar Airways'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515346259', 'utc': '1515317459'},
#      'status': {'color': 'yellow',
#       'diverted': 'None',
#       'text': 'delayed',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Delayed 17:30'},
#    'time': {'estimated': {'arrival': '1515317459', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515317459'},
#     'real': {'arrival': 'None', 'departure': '1515291736'},
#     'scheduled': {'arrival': '1515315000', 'departure': '1515286800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B38M', 'text': 'Boeing 737 MAX 8'},
#     'registration': '9V-MBA',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'Silk Air',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': '32',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'BLR', 'icao': 'VOBL'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Bengaluru Kempegowda International Airport',
#      'position': {'country': {'code': 'IN', 'name': 'India'},
#       'latitude': '13.198889',
#       'longitude': '77.705559',
#       'region': {'city': 'Bengaluru'}},
#      'timezone': {'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Kolkata',
#       'offset': '19800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SLK423',
#     'number': {'alternative': 'None', 'default': 'MI423'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344290', 'utc': '1515315490'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:58'},
#    'time': {'estimated': {'arrival': '1515315490', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315490'},
#     'real': {'arrival': 'None', 'departure': '1515300144'},
#     'scheduled': {'arrival': '1515315000', 'departure': '1515298800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A333', 'text': 'Airbus A330-343'},
#     'registration': '9V-STO',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': '35',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'NGO', 'icao': 'RJGG'},
#      'info': {'baggage': 'None', 'gate': '18', 'terminal': 'None'},
#      'name': 'Nagoya Chubu Centrair International Airport',
#      'position': {'country': {'code': 'JP', 'name': 'Japan'},
#       'latitude': '34.85841',
#       'longitude': '136.805405',
#       'region': {'city': 'Nagoya'}},
#      'timezone': {'abbr': 'JST',
#       'abbrName': 'Japan Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Tokyo',
#       'offset': '32400'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SIA671',
#     'number': {'alternative': 'None', 'default': 'SQ671'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515341617', 'utc': '1515312817'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'landed',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Landed 16:13'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': '23520', 'eta': '1515312817'},
#     'real': {'arrival': '1515312817', 'departure': '1515289289'},
#     'scheduled': {'arrival': '1515315000', 'departure': '1515288600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-TAT',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'TGW'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'info': {'baggage': '32',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'HAN', 'icao': 'VVNB'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'T2'},
#      'name': 'Hanoi Noi Bai International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '21.221189',
#       'longitude': '105.807098',
#       'region': {'city': 'Hanoi'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'TGW301',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR301'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515342956', 'utc': '1515314156'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Estimated 16:35'},
#    'time': {'estimated': {'arrival': '1515314156', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515314156'},
#     'real': {'arrival': 'None', 'departure': '1515302930'},
#     'scheduled': {'arrival': '1515315000', 'departure': '1515302400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8SA'},
#     'registration': '9V-MGI',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': '31',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'PEN', 'icao': 'WMKP'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Penang International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '5.297139',
#       'longitude': '100.276802',
#       'region': {'city': 'Penang'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SLK349',
#     'number': {'alternative': 'None', 'default': 'MI349'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515342854', 'utc': '1515314054'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'landed',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Landed 16:34'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': '4200', 'eta': '1515314054'},
#     'real': {'arrival': '1515314054', 'departure': '1515309838'},
#     'scheduled': {'arrival': '1515315300', 'departure': '1515310200'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B773', 'text': 'Boeing 777-312'},
#     'registration': '9V-SYF',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': '36',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': 'D2', 'terminal': '2'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SIA959',
#     'number': {'alternative': 'None', 'default': 'SQ959'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344256', 'utc': '1515315456'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:57'},
#    'time': {'estimated': {'arrival': '1515315456', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315456'},
#     'real': {'arrival': 'None', 'departure': '1515310677'},
#     'scheduled': {'arrival': '1515315300', 'departure': '1515309000'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B789', 'text': 'Boeing 787-9 Dreamliner'},
#     'registration': '9V-OJF',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'TGW'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'info': {'baggage': '33',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'MEL', 'icao': 'YMML'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Melbourne Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-37.673302',
#       'longitude': '144.843307',
#       'region': {'city': 'Melbourne'}},
#      'timezone': {'abbr': 'AEDT',
#       'abbrName': 'Australian Eastern Daylight Time',
#       'isDst': 'True',
#       'name': 'Australia/Melbourne',
#       'offset': '39600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'TGW019',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR19'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515343971', 'utc': '1515315171'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:52'},
#    'time': {'estimated': {'arrival': '1515315171', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315171'},
#     'real': {'arrival': 'None', 'departure': '1515289154'},
#     'scheduled': {'arrival': '1515315300', 'departure': '1515287700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-216'},
#     'registration': '9M-AFU',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'AK', 'icao': 'AXM'},
#     'name': 'AirAsia',
#     'short': 'AirAsia'},
#    'airport': {'destination': {'info': {'baggage': '7',
#       'gate': 'None',
#       'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'BKI', 'icao': 'WBKK'},
#      'info': {'baggage': 'None', 'gate': '2B', 'terminal': '1'},
#      'name': 'Kota Kinabalu International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '5.937208',
#       'longitude': '116.051102',
#       'region': {'city': 'Kota Kinabalu'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuching',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'AXM1791',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'AK1791'}},
#    'owner': {'code': {'iata': 'AK', 'icao': 'AXM'}, 'name': 'AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515343290', 'utc': '1515314490'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Estimated 16:41'},
#    'time': {'estimated': {'arrival': '1515314490', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515314490'},
#     'real': {'arrival': 'None', 'departure': '1515307347'},
#     'scheduled': {'arrival': '1515315600', 'departure': '1515306900'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-TRK',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'TGW'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'info': {'baggage': '38',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'DPS', 'icao': 'WADD'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Denpasar Ngurah Rai International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-8.74816',
#       'longitude': '115.167099',
#       'region': {'city': 'Denpasar'}},
#      'timezone': {'abbr': 'WITA',
#       'abbrName': 'Central Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Makassar',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'TGW285',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR285'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515342621', 'utc': '1515313821'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'landed',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Landed 16:30'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': '8220', 'eta': '1515313821'},
#     'real': {'arrival': '1515313821', 'departure': '1515305591'},
#     'scheduled': {'arrival': '1515315600', 'departure': '1515305100'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A388', 'text': 'Airbus A380-841'},
#     'registration': 'D-AIMM',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'LH', 'icao': 'DLH'},
#     'name': 'Lufthansa',
#     'short': 'Lufthansa'},
#    'airport': {'destination': {'info': {'baggage': '34',
#       'gate': 'E8',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'FRA', 'icao': 'EDDF'},
#      'info': {'baggage': 'None', 'gate': 'Z58', 'terminal': '1'},
#      'name': 'Frankfurt Airport',
#      'position': {'country': {'code': 'DE', 'name': 'Germany'},
#       'latitude': '50.026421',
#       'longitude': '8.543125',
#       'region': {'city': 'Frankfurt'}},
#      'timezone': {'abbr': 'CET',
#       'abbrName': 'Central European Time',
#       'isDst': 'False',
#       'name': 'Europe/Berlin',
#       'offset': '3600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'DLH778',
#     'number': {'alternative': 'None', 'default': 'LH778'}},
#    'owner': {'code': {'iata': 'LH', 'icao': 'DLH'}, 'name': 'Lufthansa'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515343384', 'utc': '1515314584'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Estimated 16:43'},
#    'time': {'estimated': {'arrival': '1515314584', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515314584'},
#     'real': {'arrival': 'None', 'departure': '1515274052'},
#     'scheduled': {'arrival': '1515315900', 'departure': '1515271800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-JSR',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JQ', 'icao': 'JST'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Airways'},
#    'airport': {'destination': {'info': {'baggage': '19',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'info': {'baggage': 'None', 'gate': 'D8', 'terminal': 'None'},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.6811',
#       'longitude': '100.7472',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'JSA516',
#     'number': {'alternative': 'None', 'default': '3K516'}},
#    'owner': {'code': {'iata': '3K', 'icao': 'JSA'}, 'name': 'Jetstar Asia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515345057', 'utc': '1515316257'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:10'},
#    'time': {'estimated': {'arrival': '1515316257', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515316257'},
#     'real': {'arrival': 'None', 'departure': '1515309264'},
#     'scheduled': {'arrival': '1515315900', 'departure': '1515306600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#     'registration': 'OH-LWK',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'AY', 'icao': 'FIN'},
#     'name': 'Finnair',
#     'short': 'Finnair'},
#    'airport': {'destination': {'info': {'baggage': '21',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'HEL', 'icao': 'EFHK'},
#      'info': {'baggage': 'None', 'gate': '53', 'terminal': '2'},
#      'name': 'Helsinki Vantaa Airport',
#      'position': {'country': {'code': 'FI', 'name': 'Finland'},
#       'latitude': '60.317219',
#       'longitude': '24.963329',
#       'region': {'city': 'Helsinki'}},
#      'timezone': {'abbr': 'EET',
#       'abbrName': 'Eastern European Time',
#       'isDst': 'False',
#       'name': 'Europe/Helsinki',
#       'offset': '7200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'FIN131',
#     'number': {'alternative': 'None', 'default': 'AY131'}},
#    'owner': {'code': {'iata': 'AY', 'icao': 'FIN'}, 'name': 'Finnair'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344256', 'utc': '1515315456'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:57'},
#    'time': {'estimated': {'arrival': '1515315456', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315456'},
#     'real': {'arrival': 'None', 'departure': '1515277302'},
#     'scheduled': {'arrival': '1515316200', 'departure': '1515275700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8SA'},
#     'registration': '9V-MGG',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': '35',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'PNH', 'icao': 'VDPP'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Phnom Penh International Airport',
#      'position': {'country': {'code': 'KH', 'name': 'Cambodia'},
#       'latitude': '11.54655',
#       'longitude': '104.844101',
#       'region': {'city': 'Phnom Penh'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Phnom_Penh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SLK605',
#     'number': {'alternative': 'None', 'default': 'MI605'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344767', 'utc': '1515315967'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:06'},
#    'time': {'estimated': {'arrival': '1515315967', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315967'},
#     'real': {'arrival': 'None', 'departure': '1515309723'},
#     'scheduled': {'arrival': '1515316200', 'departure': '1515308700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A333', 'text': 'Airbus A330-343'},
#     'registration': '9V-SSA',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': '37',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'KIX', 'icao': 'RJBB'},
#      'info': {'baggage': 'None', 'gate': '41', 'terminal': '1'},
#      'name': 'Osaka Kansai International Airport',
#      'position': {'country': {'code': 'JP', 'name': 'Japan'},
#       'latitude': '34.427299',
#       'longitude': '135.244003',
#       'region': {'city': 'Osaka'}},
#      'timezone': {'abbr': 'JST',
#       'abbrName': 'Japan Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Tokyo',
#       'offset': '32400'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SIA619',
#     'number': {'alternative': 'None', 'default': 'SQ619'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515345024', 'utc': '1515316224'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:10'},
#    'time': {'estimated': {'arrival': '1515316224', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515316224'},
#     'real': {'arrival': 'None', 'departure': '1515292687'},
#     'scheduled': {'arrival': '1515316200', 'departure': '1515290400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B772', 'text': 'Boeing 777-2D7(ER)'},
#     'registration': 'HS-TJT',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TG', 'icao': 'THA'},
#     'name': 'Thai Airways',
#     'short': 'Thai Airways'},
#    'airport': {'destination': {'info': {'baggage': '18',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'info': {'baggage': 'None', 'gate': 'C7', 'terminal': 'None'},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.6811',
#       'longitude': '100.7472',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'THA407',
#     'number': {'alternative': 'None', 'default': 'TG407'}},
#    'owner': {'code': {'iata': 'TG', 'icao': 'THA'}, 'name': 'Thai Airways'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515345024', 'utc': '1515316224'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:10'},
#    'time': {'estimated': {'arrival': '1515316224', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515316224'},
#     'real': {'arrival': 'None', 'departure': '1515308884'},
#     'scheduled': {'arrival': '1515316200', 'departure': '1515307800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8SA'},
#     'registration': '9V-MGA',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': '34',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'KMG', 'icao': 'ZPPP'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Kunming Changshui International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '25.101944',
#       'longitude': '102.929169',
#       'region': {'city': 'Kunming'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Chongqing',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SLK913',
#     'number': {'alternative': 'None', 'default': 'MI913'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344914', 'utc': '1515316114'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:08'},
#    'time': {'estimated': {'arrival': '1515316114', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515316114'},
#     'real': {'arrival': 'None', 'departure': '1515302892'},
#     'scheduled': {'arrival': '1515316500', 'departure': '1515301500'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B772', 'text': 'Boeing 777-212(ER)'},
#     'registration': '9V-SVG',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': '35',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'HAN', 'icao': 'VVNB'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Hanoi Noi Bai International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '21.221189',
#       'longitude': '105.807098',
#       'region': {'city': 'Hanoi'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SIA175',
#     'number': {'alternative': 'None', 'default': 'SQ175'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344256', 'utc': '1515315456'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 16:57'},
#    'time': {'estimated': {'arrival': '1515315456', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315456'},
#     'real': {'arrival': 'None', 'departure': '1515303961'},
#     'scheduled': {'arrival': '1515316500', 'departure': '1515303300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B77W', 'text': 'Boeing 777-312(ER)'},
#     'registration': '9V-SWB',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': '43',
#       'gate': 'None',
#       'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'FRA', 'icao': 'EDDF'},
#      'info': {'baggage': 'None', 'gate': 'B46', 'terminal': '1'},
#      'name': 'Frankfurt Airport',
#      'position': {'country': {'code': 'DE', 'name': 'Germany'},
#       'latitude': '50.026421',
#       'longitude': '8.543125',
#       'region': {'city': 'Frankfurt'}},
#      'timezone': {'abbr': 'CET',
#       'abbrName': 'Central European Time',
#       'isDst': 'False',
#       'name': 'Europe/Berlin',
#       'offset': '3600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'SIA325',
#     'number': {'alternative': 'None', 'default': 'SQ325'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515343488', 'utc': '1515314688'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Estimated 16:44'},
#    'time': {'estimated': {'arrival': '1515314688', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515314688'},
#     'real': {'arrival': 'None', 'departure': '1515273545'},
#     'scheduled': {'arrival': '1515316500', 'departure': '1515272100'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-JSE',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JQ', 'icao': 'JST'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Airways'},
#    'airport': {'destination': {'info': {'baggage': '23',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'PKU', 'icao': 'WIBB'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Pekanbaru Sultan Syarif Kasim II Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '0.460786',
#       'longitude': '101.444504',
#       'region': {'city': 'Pekanbaru'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'JSA232',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': '3K232'}},
#    'owner': {'code': {'iata': '3K', 'icao': 'JSA'}, 'name': 'Jetstar Asia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515342742', 'utc': '1515313942'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'landed',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Landed 16:32'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': '2280', 'eta': '1515313942'},
#     'real': {'arrival': '1515313942', 'departure': '1515311668'},
#     'scheduled': {'arrival': '1515316500', 'departure': '1515312600'}}}},
#  {'flight': {'aircraft': 'None',
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CKG', 'icao': 'ZUCK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'T3'},
#      'name': 'Chongqing Jiangbei International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '29.71921',
#       'longitude': '106.641602',
#       'region': {'city': 'Chongqing'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Chongqing',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'MI971'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515316500', 'departure': '1515298200'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-216'},
#     'registration': 'PK-AXT',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'AK', 'icao': 'AXM'},
#     'name': 'AirAsia',
#     'short': 'AirAsia'},
#    'airport': {'destination': {'info': {'baggage': '5',
#       'gate': 'None',
#       'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': 'E4', 'terminal': '2'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'AWQ266',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'QZ266'}},
#    'owner': {'code': {'iata': 'QZ', 'icao': 'AWQ'},
#     'name': 'Indonesia AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515347771', 'utc': '1515318971'},
#      'status': {'color': 'yellow',
#       'diverted': 'None',
#       'text': 'delayed',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Delayed 17:56'},
#    'time': {'estimated': {'arrival': '1515318971', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515318971'},
#     'real': {'arrival': 'None', 'departure': '1515314271'},
#     'scheduled': {'arrival': '1515316800', 'departure': '1515309900'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A332', 'text': 'Airbus A330-202'},
#     'registration': 'VH-EBR',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'QF', 'icao': 'QFA'},
#     'name': 'Qantas',
#     'short': 'Qantas'},
#    'airport': {'destination': {'info': {'baggage': '18',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'MEL', 'icao': 'YMML'},
#      'info': {'baggage': 'None', 'gate': '12', 'terminal': '2'},
#      'name': 'Melbourne Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-37.673302',
#       'longitude': '144.843307',
#       'region': {'city': 'Melbourne'}},
#      'timezone': {'abbr': 'AEDT',
#       'abbrName': 'Australian Eastern Daylight Time',
#       'isDst': 'True',
#       'name': 'Australia/Melbourne',
#       'offset': '39600'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'QFA35',
#     'number': {'alternative': 'None', 'default': 'QF35'}},
#    'owner': {'code': {'iata': 'QF', 'icao': 'QFA'}, 'name': 'Qantas'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': '1515344543', 'utc': '1515315743'},
#      'status': {'color': 'green',
#       'diverted': 'None',
#       'text': 'estimated',
#       'type': 'arrival'}},
#     'live': 'True',
#     'text': 'Estimated 17:02'},
#    'time': {'estimated': {'arrival': '1515315743', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': '1515315743'},
#     'real': {'arrival': 'None', 'departure': '1515289219'},
#     'scheduled': {'arrival': '1515317100', 'departure': '1515288300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A321', 'text': 'Airbus A321-231'},
#     'registration': 'VN-A615',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'VN', 'icao': 'HVN'},
#     'name': 'Vietnam Airlines',
#     'short': 'Vietnam Airlines'},
#    'airport': {'destination': {'info': {'baggage': '1',
#       'gate': 'None',
#       'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'SGN', 'icao': 'VVTS'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Ho Chi Minh City International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '10.81879',
#       'longitude': '106.651802',
#       'region': {'city': 'Ho Chi Minh City'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'HVN655',
#     'number': {'alternative': 'None', 'default': 'VN655'}},
#    'owner': {'code': {'iata': 'VN', 'icao': 'HVN'},
#     'name': 'Vietnam Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
# ...
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': 'None'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'info': {'baggage': 'None', 'gate': 'D7', 'terminal': 'None'},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.6811',
#       'longitude': '100.7472',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ977'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515323700', 'departure': '1515314400'}}}},
#  {'flight': {'aircraft': {'model': {'code': '333', 'text': ''},
#     'registration': '',
#     'serialNo': ''},
#    'airline': {'code': {'iata': 'GA', 'icao': 'GIA'},
#     'name': 'Garuda Indonesia',
#     'short': 'Garuda Indonesia'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': 'U10', 'terminal': '3U'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'GA838'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324000', 'departure': '1515317400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A319', 'text': 'Airbus A319-132'},
#     'registration': 'HS-PGZ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'PG', 'icao': 'BKP'},
#     'name': 'Bangkok Airways',
#     'short': 'Bangkok Airways'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'USM', 'icao': 'VTSM'},
#      'info': {'baggage': 'None', 'gate': '7', 'terminal': '1'},
#      'name': 'Koh Samui Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '9.547794',
#       'longitude': '100.062202',
#       'region': {'city': 'Koh Samui'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'PG961'}},
#    'owner': {'code': {'iata': 'PG', 'icao': 'BKP'}, 'name': 'Bangkok Airways'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324000', 'departure': '1515317100'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A333', 'text': 'Airbus A330-343'},
#     'registration': '9V-STA',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': 'None'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'SGN', 'icao': 'VVTS'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Ho Chi Minh City International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '10.81879',
#       'longitude': '106.651802',
#       'region': {'city': 'Ho Chi Minh City'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ183'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324000', 'departure': '1515316500'}}}},
#  {'flight': {'aircraft': {'model': {'code': '321', 'text': ''},
#     'registration': '',
#     'serialNo': ''},
#    'airline': {'code': {'iata': 'VN', 'icao': 'HVN'},
#     'name': 'Vietnam Airlines',
#     'short': 'Vietnam Airlines'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'SGN', 'icao': 'VVTS'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Ho Chi Minh City International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '10.81879',
#       'longitude': '106.651802',
#       'region': {'city': 'Ho Chi Minh City'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'VN659'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324300', 'departure': '1515316800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-JSH',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JQ', 'icao': 'JST'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Airways'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': 'D4', 'terminal': '2'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': '3K204'}},
#    'owner': {'code': {'iata': '3K', 'icao': 'JSA'}, 'name': 'Jetstar Asia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324300', 'departure': '1515317700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-JSN',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JQ', 'icao': 'JST'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Airways'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'REP', 'icao': 'VDSR'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Siem Reap International Airport',
#      'position': {'country': {'code': 'KH', 'name': 'Cambodia'},
#       'latitude': '13.41066',
#       'longitude': '103.812798',
#       'region': {'city': 'Siem Reap'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Phnom_Penh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'JSA602',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': '3K602'}},
#    'owner': {'code': {'iata': '3K', 'icao': 'JSA'}, 'name': 'Jetstar Asia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324300', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-233'},
#     'registration': '9V-SLP',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'JOG', 'icao': 'WAHH'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Yogyakarta Adisucipto International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-7.78818',
#       'longitude': '110.431702',
#       'region': {'city': 'Yogyakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'MI153'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324600', 'departure': '1515316200'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B38M', 'text': 'Boeing 737 MAX 8'},
#     'registration': '9V-MBB',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'info': {'baggage': 'None',
#       'gate': 'None',
#       'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'origin': {'code': {'iata': 'PEN', 'icao': 'WMKP'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Penang International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '5.297139',
#       'longitude': '100.276802',
#       'region': {'city': 'Penang'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'MI351'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'arrival'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324600', 'departure': '1515319500'}}}}]

# %%
api.get_airport_departures('sin')
# Out:
# [{'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B788', 'text': 'Boeing 787-8 Dreamliner'},
#     'registration': '9V-OFB',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'HGH', 'icao': 'ZSHC'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Hangzhou Xiaoshan International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '30.2295',
#       'longitude': '120.434402',
#       'region': {'city': 'Hangzhou'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '10', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR188'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515332700', 'departure': '1515314700'}}}},
#  {'flight': {'aircraft': {'model': {'code': '320', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'HKG', 'icao': 'VHHH'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '1'},
#      'name': 'Hong Kong International Airport',
#      'position': {'country': {'code': 'HK', 'name': 'Hong Kong'},
#       'latitude': '22.30888',
#       'longitude': '113.914703',
#       'region': {'city': 'Hong Kong'}},
#      'timezone': {'abbr': 'HKT',
#       'abbrName': 'Hong Kong Time',
#       'isDst': 'False',
#       'name': 'Asia/Hong_Kong',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F30', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR974'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515328200', 'departure': '1515314700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-81D'},
#     'registration': 'PK-GFR',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'GA', 'icao': 'GIA'},
#     'name': 'Garuda Indonesia',
#     'short': 'Garuda Indonesia'},
#    'airport': {'destination': {'code': {'iata': 'DPS', 'icao': 'WADD'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Denpasar Ngurah Rai International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-8.74816',
#       'longitude': '115.167099',
#       'region': {'city': 'Denpasar'}},
#      'timezone': {'abbr': 'WITA',
#       'abbrName': 'Central Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Makassar',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'A9', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'GA841'}},
#    'owner': {'code': {'iata': 'GA', 'icao': 'GIA'},
#     'name': 'Garuda Indonesia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515325800', 'departure': '1515315300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B77W', 'text': 'Boeing 777-312(ER)'},
#     'registration': '9V-SWP',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'PEK', 'icao': 'ZBAA'},
#      'info': {'baggage': '37', 'gate': 'None', 'terminal': '3'},
#      'name': 'Beijing Capital International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '40.080109',
#       'longitude': '116.584503',
#       'region': {'city': 'Beijing'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'B8', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ806'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515337200', 'departure': '1515315300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#     'registration': 'RP-C3238',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': '5J', 'icao': 'CEB'},
#     'name': 'Cebu Pacific',
#     'short': 'Cebu Pacific'},
#    'airport': {'destination': {'code': {'iata': 'CRK', 'icao': 'RPLC'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Angeles City Clark International Airport',
#      'position': {'country': {'code': 'PH', 'name': 'Philippines'},
#       'latitude': '15.18598',
#       'longitude': '120.560303',
#       'region': {'city': 'Angeles City'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Manila',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G2', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': '5J538'}},
#    'owner': {'code': {'iata': '5J', 'icao': 'CEB'}, 'name': 'Cebu Pacific'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515328800', 'departure': '1515315300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'AT75', 'text': 'ATR 72-500'},
#     'registration': '9M-FYC',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'FY', 'icao': 'FFM'},
#     'name': 'Firefly',
#     'short': 'Firefly'},
#    'airport': {'destination': {'code': {'iata': 'SZB', 'icao': 'WMSA'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Kuala Lumpur Subang Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '3.130583',
#       'longitude': '101.549301',
#       'region': {'city': 'Kuala Lumpur'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '09', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'FY3510'}},
#    'owner': {'code': {'iata': 'FY', 'icao': 'FFM'}, 'name': 'Firefly'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515320400', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8SA'},
#     'registration': '9V-MGN',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'code': {'iata': 'REP', 'icao': 'VDSR'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Siem Reap International Airport',
#      'position': {'country': {'code': 'KH', 'name': 'Cambodia'},
#       'latitude': '13.41066',
#       'longitude': '103.812798',
#       'region': {'city': 'Siem Reap'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Phnom_Penh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'E6', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'MI618'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515322800', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8LW'},
#     'registration': 'B-1561',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'NS', 'icao': 'HBH'},
#     'name': 'Hebei Airlines',
#     'short': 'Hebei Airlines'},
#    'airport': {'destination': {'code': {'iata': 'HGH', 'icao': 'ZSHC'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Hangzhou Xiaoshan International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '30.2295',
#       'longitude': '120.434402',
#       'region': {'city': 'Hangzhou'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'C19', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'NS3528'}},
#    'owner': {'code': {'iata': 'NS', 'icao': 'HBH'}, 'name': 'Hebei Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515333000', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8GP'},
#     'registration': '9M-LNQ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'OD', 'icao': 'MXD'},
#     'name': 'Malindo Air',
#     'short': 'Batik Air Malaysia'},
#    'airport': {'destination': {'code': {'iata': 'KUL', 'icao': 'WMKK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'M'},
#      'name': 'Kuala Lumpur International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '2.745578',
#       'longitude': '101.7099',
#       'region': {'city': 'Kuala Lumpur'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'A17', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'OD808'}},
#    'owner': {'code': {'iata': 'OD', 'icao': 'MXD'},
#     'name': 'Batik Air Malaysia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515319200', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A321', 'text': 'Airbus A321-211'},
#     'registration': 'VN-A632',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'VJ', 'icao': 'VJC'},
#     'name': 'VietJet Air',
#     'short': 'VietJet Air'},
#    'airport': {'destination': {'code': {'iata': 'SGN', 'icao': 'VVTS'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Ho Chi Minh City International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '10.81879',
#       'longitude': '106.651802',
#       'region': {'city': 'Ho Chi Minh City'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '11', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'VJ814'}},
#    'owner': {'code': {'iata': 'VJ', 'icao': 'VJC'}, 'name': 'VietJet Air'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515323100', 'departure': '1515315600'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A20N', 'text': 'Airbus A320-251N'},
#     'registration': 'HS-BBZ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'FD', 'icao': 'AIQ'},
#     'name': 'AirAsia',
#     'short': 'Thai AirAsia'},
#    'airport': {'destination': {'code': {'iata': 'DMK', 'icao': 'VTBD'},
#      'info': {'baggage': '4', 'gate': 'None', 'terminal': '1'},
#      'name': 'Bangkok Don Mueang International Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.9125',
#       'longitude': '100.606697',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G12', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'FD354'}},
#    'owner': {'code': {'iata': 'FD', 'icao': 'AIQ'}, 'name': 'Thai AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324900', 'departure': '1515315900'}}}},
#  {'flight': {'aircraft': {'model': {'code': '77W', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'PVG', 'icao': 'ZSPD'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Shanghai Pudong International Airport',
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '31.14337',
#       'longitude': '121.805199',
#       'region': {'city': 'Shanghai'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'B10', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ836'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515334800', 'departure': '1515315900'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B739', 'text': 'Boeing 737-9GP(ER)'},
#     'registration': 'PK-LHO',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'JT', 'icao': 'LNI'},
#     'name': 'Lion Air',
#     'short': 'Lion Airlines'},
#    'airport': {'destination': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': '05', 'terminal': '2'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '01', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'JT157'}},
#    'owner': {'code': {'iata': 'JT', 'icao': 'LNI'}, 'name': 'Lion Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515323100', 'departure': '1515316500'}}}},
#  {'flight': {'aircraft': {'model': {'code': '320', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'KUL', 'icao': 'WMKK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Kuala Lumpur International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '2.745578',
#       'longitude': '101.7099',
#       'region': {'city': 'Kuala Lumpur'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F56', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR468'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515320400', 'departure': '1515316500'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A319', 'text': 'Airbus A319-131'},
#     'registration': 'HS-PPG',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'PG', 'icao': 'BKP'},
#     'name': 'Bangkok Airways',
#     'short': 'Bangkok Airways'},
#    'airport': {'destination': {'code': {'iata': 'USM', 'icao': 'VTSM'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Koh Samui Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '9.547794',
#       'longitude': '100.062202',
#       'region': {'city': 'Koh Samui'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'D36', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'PG964'}},
#    'owner': {'code': {'iata': 'PG', 'icao': 'BKP'}, 'name': 'Bangkok Airways'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515323700', 'departure': '1515316800'}}}},
#  {'flight': {'aircraft': {'model': {'code': '333', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': '02', 'terminal': '2'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F42', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ964'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515323100', 'departure': '1515316800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-TAZ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'MNL', 'icao': 'RPLL'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '1'},
#      'name': 'Manila Ninoy Aquino International Airport',
#      'position': {'country': {'code': 'PH', 'name': 'Philippines'},
#       'latitude': '14.50864',
#       'longitude': '121.019501',
#       'region': {'city': 'Manila'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Manila',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '10', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR374'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515329700', 'departure': '1515316800'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8FH'},
#     'registration': '9M-MLE',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MH', 'icao': 'MAS'},
#     'name': 'Malaysia Airlines',
#     'short': 'Malaysia Airlines'},
#    'airport': {'destination': {'code': {'iata': 'KUL', 'icao': 'WMKK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'M'},
#      'name': 'Kuala Lumpur International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '2.745578',
#       'longitude': '101.7099',
#       'region': {'city': 'Kuala Lumpur'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F52', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'MH608'}},
#    'owner': {'code': {'iata': 'MH', 'icao': 'MAS'},
#     'name': 'Malaysia Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515320700', 'departure': '1515317100'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-87L'},
#     'registration': 'B-1973',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'ZH', 'icao': 'CSZ'},
#     'name': 'Shenzhen Airlines',
#     'short': 'Shenzhen Airlines'},
#    'airport': {'destination': {'code': {'iata': 'SZX', 'icao': 'ZGSZ'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'T3'},
#      'name': "Shenzhen Bao'an International Airport",
#      'position': {'country': {'code': 'CN', 'name': 'China'},
#       'latitude': '22.63925',
#       'longitude': '113.8106',
#       'region': {'city': 'Shenzhen'}},
#      'timezone': {'abbr': 'CST',
#       'abbrName': 'China Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Shanghai',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'D44', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'ZH9024'}},
#    'owner': {'code': {'iata': 'ZH', 'icao': 'CSZ'},
#     'name': 'Shenzhen Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515333600', 'departure': '1515317100'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-214'},
#     'registration': 'PK-AZI',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'QZ', 'icao': 'AWQ'},
#     'name': 'AirAsia',
#     'short': 'Indonesia AirAsia'},
#    'airport': {'destination': {'code': {'iata': 'DPS', 'icao': 'WADD'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Denpasar Ngurah Rai International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-8.74816',
#       'longitude': '115.167099',
#       'region': {'city': 'Denpasar'}},
#      'timezone': {'abbr': 'WITA',
#       'abbrName': 'Central Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Makassar',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G10', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'QZ507'}},
#    'owner': {'code': {'iata': 'QZ', 'icao': 'AWQ'},
#     'name': 'Indonesia AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515327300', 'departure': '1515317400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-TAT',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'info': {'baggage': '22', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.6811',
#       'longitude': '100.7472',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'E24', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR616'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515326100', 'departure': '1515317400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-232'},
#     'registration': '9V-JSF',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': '3K', 'icao': 'JSA'},
#     'name': 'Jetstar Airways',
#     'short': 'Jetstar Asia'},
#    'airport': {'destination': {'code': {'iata': 'RGN', 'icao': 'VYYY'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Yangon International Airport',
#      'position': {'country': {'code': 'MM', 'name': 'Myanmar (Burma)'},
#       'latitude': '16.907301',
#       'longitude': '96.133217',
#       'region': {'city': 'Yangon'}},
#      'timezone': {'abbr': '+0630',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Rangoon',
#       'offset': '23400'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'C24', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': '3K583'}},
#    'owner': {'code': {'iata': '3K', 'icao': 'JSA'}, 'name': 'Jetstar Asia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515327900', 'departure': '1515317400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-216'},
#     'registration': '9M-AFU',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'AK', 'icao': 'AXM'},
#     'name': 'AirAsia',
#     'short': 'AirAsia'},
#    'airport': {'destination': {'code': {'iata': 'BKI', 'icao': 'WBKK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '1'},
#      'name': 'Kota Kinabalu International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '5.937208',
#       'longitude': '116.051102',
#       'region': {'city': 'Kota Kinabalu'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuching',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G7', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'AK1792'}},
#    'owner': {'code': {'iata': 'AK', 'icao': 'AXM'}, 'name': 'AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515326700', 'departure': '1515317700'}}}},
#  {'flight': {'aircraft': {'model': {'code': '738', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'GA', 'icao': 'GIA'},
#     'name': 'Garuda Indonesia',
#     'short': 'Garuda Indonesia'},
#    'airport': {'destination': {'code': {'iata': 'CGK', 'icao': 'WIII'},
#      'info': {'baggage': 'None', 'gate': 'U6', 'terminal': '3U'},
#      'name': 'Jakarta Soekarno Hatta International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-6.12556',
#       'longitude': '106.6558',
#       'region': {'city': 'Jakarta'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'A16', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'GA835'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515324600', 'departure': '1515317700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B77W', 'text': 'Boeing 777-306(ER)'},
#     'registration': 'PH-BVG',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'KL', 'icao': 'KLM'},
#     'name': 'KLM',
#     'short': 'KLM'},
#    'airport': {'destination': {'code': {'iata': 'DPS', 'icao': 'WADD'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Denpasar Ngurah Rai International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-8.74816',
#       'longitude': '115.167099',
#       'region': {'city': 'Denpasar'}},
#      'timezone': {'abbr': 'WITA',
#       'abbrName': 'Central Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Makassar',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'D32', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'KL835'}},
#    'owner': {'code': {'iata': 'KL', 'icao': 'KLM'}, 'name': 'KLM'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515327300', 'departure': '1515317700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A333', 'text': 'Airbus A330-343'},
#     'registration': '9V-SSD',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'SGN', 'icao': 'VVTS'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Ho Chi Minh City International Airport',
#      'position': {'country': {'code': 'VN', 'name': 'Vietnam'},
#       'latitude': '10.81879',
#       'longitude': '106.651802',
#       'region': {'city': 'Ho Chi Minh City'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Ho_Chi_Minh',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F50', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ186'}},
#    'owner': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515325500', 'departure': '1515317700'}}}},
#  {'flight': {'aircraft': {'model': {'code': '772', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'BKK', 'icao': 'VTBS'},
#      'info': {'baggage': '11', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Bangkok Suvarnabhumi Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '13.6811',
#       'longitude': '100.7472',
#       'region': {'city': 'Bangkok'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'E11', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ982'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
# ...
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'TR', 'icao': 'SCO'},
#     'name': 'Scoot',
#     'short': 'Scoot'},
#    'airport': {'destination': {'code': {'iata': 'JAI', 'icao': 'VIJP'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Jaipur Airport',
#      'position': {'country': {'code': 'IN', 'name': 'India'},
#       'latitude': '26.82419',
#       'longitude': '75.812157',
#       'region': {'city': 'Jaipur'}},
#      'timezone': {'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Kolkata',
#       'offset': '19800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': '10', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'TR518'}},
#    'owner': {'code': {'iata': 'TR', 'icao': 'TGW'}, 'name': 'Scoot'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515348300', 'departure': '1515326400'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B77W', 'text': 'Boeing 777-336(ER)'},
#     'registration': 'G-STBK',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'BA', 'icao': 'BAW'},
#     'name': 'British Airways',
#     'short': 'British Airways'},
#    'airport': {'destination': {'code': {'iata': 'SYD', 'icao': 'YSSY'},
#      'info': {'baggage': 'None', 'gate': '61', 'terminal': '1'},
#      'name': 'Sydney Kingsford Smith Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-33.946098',
#       'longitude': '151.1772',
#       'region': {'city': 'Sydney'}},
#      'timezone': {'abbr': 'AEDT',
#       'abbrName': 'Australian Eastern Daylight Time',
#       'isDst': 'True',
#       'name': 'Australia/Sydney',
#       'offset': '39600'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'C11', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'BA15'}},
#    'owner': {'code': {'iata': 'BA', 'icao': 'BAW'}, 'name': 'British Airways'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515354600', 'departure': '1515326700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A333', 'text': 'Airbus A330-302'},
#     'registration': 'B-18301',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'CI', 'icao': 'CAL'},
#     'name': 'China Airlines',
#     'short': 'China Airlines'},
#    'airport': {'destination': {'code': {'iata': 'SUB', 'icao': 'WARR'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Surabaya Juanda International Airport',
#      'position': {'country': {'code': 'ID', 'name': 'Indonesia'},
#       'latitude': '-7.37983',
#       'longitude': '112.786797',
#       'region': {'city': 'Surabaya'}},
#      'timezone': {'abbr': 'WIB',
#       'abbrName': 'Western Indonesian Time',
#       'isDst': 'False',
#       'name': 'Asia/Jakarta',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'A15', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'CI751'}},
#    'owner': {'code': {'iata': 'CI', 'icao': 'CAL'}, 'name': 'China Airlines'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515335400', 'departure': '1515326700'}}}},
#  {'flight': {'aircraft': {'model': {'code': '772', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'SQ', 'icao': 'SIA'},
#     'name': 'Singapore Airlines',
#     'short': 'Singapore Airlines'},
#    'airport': {'destination': {'code': {'iata': 'BLR', 'icao': 'VOBL'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Bengaluru Kempegowda International Airport',
#      'position': {'country': {'code': 'IN', 'name': 'India'},
#       'latitude': '13.198889',
#       'longitude': '77.705559',
#       'region': {'city': 'Bengaluru'}},
#      'timezone': {'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Kolkata',
#       'offset': '19800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'A21', 'terminal': '3'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'SQ502'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515342300', 'departure': '1515326700'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'B738', 'text': 'Boeing 737-8SA'},
#     'registration': '9V-MGJ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'MI', 'icao': 'SLK'},
#     'name': 'SilkAir',
#     'short': 'SilkAir'},
#    'airport': {'destination': {'code': {'iata': 'COK', 'icao': 'VOCI'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '3'},
#      'name': 'Cochin International Airport',
#      'position': {'country': {'code': 'IN', 'name': 'India'},
#       'latitude': '10.15199',
#       'longitude': '76.401901',
#       'region': {'city': 'Cochin'}},
#      'timezone': {'abbr': 'IST',
#       'abbrName': 'India Standard Time',
#       'isDst': 'False',
#       'name': 'Asia/Kolkata',
#       'offset': '19800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'F36', 'terminal': '2'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'MI468'}},
#    'owner': {'code': {'iata': 'MI', 'icao': 'SLK'}, 'name': 'SilkAir'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515342900', 'departure': '1515327000'}}}},
#  {'flight': {'aircraft': {'model': {'code': '319', 'text': ''},
#     'registration': ''},
#    'airline': {'code': {'iata': 'PG', 'icao': 'BKP'},
#     'name': 'Bangkok Airways',
#     'short': 'Bangkok Airways'},
#    'airport': {'destination': {'code': {'iata': 'USM', 'icao': 'VTSM'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'None'},
#      'name': 'Koh Samui Airport',
#      'position': {'country': {'code': 'TH', 'name': 'Thailand'},
#       'latitude': '9.547794',
#       'longitude': '100.062202',
#       'region': {'city': 'Koh Samui'}},
#      'timezone': {'abbr': '+07',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Bangkok',
#       'offset': '25200'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'D47', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'PG962'}},
#    'owner': 'None',
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515333900', 'departure': '1515327000'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A332', 'text': 'Airbus A330-202'},
#     'registration': 'VH-EBS',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'QF', 'icao': 'QFA'},
#     'name': 'Qantas',
#     'short': 'Qantas'},
#    'airport': {'destination': {'code': {'iata': 'BNE', 'icao': 'YBBN'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': 'I'},
#      'name': 'Brisbane Airport',
#      'position': {'country': {'code': 'AU', 'name': 'Australia'},
#       'latitude': '-27.3841',
#       'longitude': '153.117493',
#       'region': {'city': 'Brisbane'}},
#      'timezone': {'abbr': 'AEST',
#       'abbrName': 'Australian Eastern Standard Time',
#       'isDst': 'False',
#       'name': 'Australia/Brisbane',
#       'offset': '36000'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'None', 'terminal': '1'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'QF52'}},
#    'owner': {'code': {'iata': 'QF', 'icao': 'QFA'}, 'name': 'Qantas'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'red',
#       'diverted': 'None',
#       'text': 'canceled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Canceled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515355500', 'departure': '1515327000'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A320', 'text': 'Airbus A320-216'},
#     'registration': '9M-AHQ',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'AK', 'icao': 'AXM'},
#     'name': 'AirAsia',
#     'short': 'AirAsia'},
#    'airport': {'destination': {'code': {'iata': 'KUL', 'icao': 'WMKK'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '2'},
#      'name': 'Kuala Lumpur International Airport',
#      'position': {'country': {'code': 'MY', 'name': 'Malaysia'},
#       'latitude': '2.745578',
#       'longitude': '101.7099',
#       'region': {'city': 'Kuala Lumpur'}},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Kuala_Lumpur',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G8', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'AK718'}},
#    'owner': {'code': {'iata': 'AK', 'icao': 'AXM'}, 'name': 'AirAsia'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515331200', 'departure': '1515327300'}}}},
#  {'flight': {'aircraft': {'age': {'availability': 'True'},
#     'availability': {'age': 'True', 'serialNo': 'True'},
#     'model': {'code': 'A359', 'text': 'Airbus A350-941'},
#     'registration': 'B-LRC',
#     'serialNo': 'None'},
#    'airline': {'code': {'iata': 'CX', 'icao': 'CPA'},
#     'name': 'Cathay Pacific',
#     'short': 'Cathay Pacific'},
#    'airport': {'destination': {'code': {'iata': 'HKG', 'icao': 'VHHH'},
#      'info': {'baggage': 'None', 'gate': 'None', 'terminal': '1'},
#      'name': 'Hong Kong International Airport',
#      'position': {'country': {'code': 'HK', 'name': 'Hong Kong'},
#       'latitude': '22.30888',
#       'longitude': '113.914703',
#       'region': {'city': 'Hong Kong'}},
#      'timezone': {'abbr': 'HKT',
#       'abbrName': 'Hong Kong Time',
#       'isDst': 'False',
#       'name': 'Asia/Hong_Kong',
#       'offset': '28800'},
#      'visible': 'True'},
#     'origin': {'info': {'baggage': 'None', 'gate': 'G20', 'terminal': '4'},
#      'timezone': {'abbr': '+08',
#       'abbrName': 'None',
#       'isDst': 'False',
#       'name': 'Asia/Singapore',
#       'offset': '28800'}},
#     'real': 'None'},
#    'identification': {'callsign': 'None',
#     'codeshare': 'None',
#     'number': {'alternative': 'None', 'default': 'CX636'}},
#    'owner': {'code': {'iata': 'CX', 'icao': 'CPA'}, 'name': 'Cathay Pacific'},
#    'status': {'ambiguous': 'False',
#     'estimated': 'None',
#     'generic': {'eventTime': {'local': 'None', 'utc': 'None'},
#      'status': {'color': 'gray',
#       'diverted': 'None',
#       'text': 'scheduled',
#       'type': 'departure'}},
#     'live': 'False',
#     'text': 'Scheduled'},
#    'time': {'estimated': {'arrival': 'None', 'departure': 'None'},
#     'other': {'duration': 'None', 'eta': 'None'},
#     'real': {'arrival': 'None', 'departure': 'None'},
#     'scheduled': {'arrival': '1515341100', 'departure': '1515327300'}}}}]

# %%
api.get_airport_details('sin')
# Out:
# {'code': {'iata': 'SIN', 'icao': 'WSSS'},
#  'delayIndex': {'arrivals': '0.42', 'departures': '2.08'},
#  'name': 'Singapore Changi Airport',
#  'position': {'country': {'code': 'SG', 'name': 'Singapore'},
#   'elevation': '22',
#   'latitude': '1.350189',
#   'longitude': '103.9944',
#   'region': {'city': 'Singapore'}},
#  'stats': {'arrivals': {'delayAvg': '5',
#    'delayIndex': '0.42',
#    'percentage': {'canceled': '0', 'delayed': '0.18', 'trend': 'static'},
#    'recent': {'delayAvg': '5',
#     'delayIndex': '0.42',
#     'percentage': {'canceled': '0', 'delayed': '0.18', 'trend': 'static'},
#     'quantity': {'canceled': '0', 'delayed': '9', 'onTime': '42'}},
#    'today': {'percentage': {'canceled': '0', 'delayed': '0.08'},
#     'quantity': {'canceled': '0', 'delayed': '41', 'onTime': '249'}},
#    'tomorrow': {'percentage': {'canceled': '0'},
#     'quantity': {'canceled': '0'}},
#    'yesterday': {'percentage': {'canceled': '0', 'delayed': '0.15'},
#     'quantity': {'canceled': '1', 'delayed': '77', 'onTime': '430'}}},
#   'departures': {'delayAvg': '25',
#    'delayIndex': '2.08',
#    'percentage': {'canceled': '0', 'delayed': '0.86', 'trend': 'static'},
#    'recent': {'delayAvg': '25',
#     'delayIndex': '2.08',
#     'percentage': {'canceled': '0', 'delayed': '0.86', 'trend': 'static'},
#     'quantity': {'canceled': '0', 'delayed': '37', 'onTime': '6'}},
#    'today': {'percentage': {'canceled': '0.01', 'delayed': '0.4'},
#     'quantity': {'canceled': '3', 'delayed': '214', 'onTime': '111'}},
#    'tomorrow': {'percentage': {'canceled': '0'},
#     'quantity': {'canceled': '0'}},
#    'yesterday': {'percentage': {'canceled': '0', 'delayed': '0.61'},
#     'quantity': {'canceled': '0', 'delayed': '306', 'onTime': '197'}}}},
#  'timezone': {'abbr': '+08',
#   'abbrName': 'None',
#   'isDst': 'False',
#   'name': 'Asia/Singapore',
#   'offset': '28800'},
#  'url': {'homepage': 'http://www.changiairport.com/',
#   'webcam': 'None',
#   'wikipedia': 'https://en.wikipedia.org/wiki/Singapore_Changi_Airport'},
#  'visible': 'True'}
